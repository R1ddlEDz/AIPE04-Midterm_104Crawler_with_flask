# %%
import requests
from bs4 import BeautifulSoup as bs
import re
from pprint import pprint
custom_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Safari/537.36",
    "Referer" : "https://www.104.com.tw/jobs/search/?"
}

url = r'https://www.104.com.tw/jobs/search/api/jobs?area=6001001000&jobsource=index_s&keyword=python&mode=s&order=15&page=1&pagesize=20'
res = requests.get(url,headers=custom_headers)

kw=""
key_word = f'{kw}='
print(res.status_code)
data = res.json()
#cleaned = 
pprint(data)
# Out:
# 200
# {'data': [{'acceptRole': [],
#            'appearDate': '20260805',
#            'applyCnt': 4,
#            'applyDate': None,
#            'coIndustry': 1012001004,
#            'coIndustryDesc': '其他醫療保健服務業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/8000/70824858000/logo.jpg?v=20251110171927',
#            'custName': '台灣大昌華嘉股份有限公司',
#            'custNo': '70824858000',
#            'd3': '',
#            'descSnippet': 'About the Role:\n'
#                           'As a Data Analytics Engineer, you are the strategic '
#                           'link between data engineering and business '
#                           'intelligence at DKSH, owning the design, '
#                           'implementation, and governance of the data '
#                           'transformation architecture that powers reliable, '
#                           'high-performance decision-making. You will convert '
#                           'a complex landscape of raw SQL data sources into a '
#                           'structured, intuitive semantic layer, giving '
#                           'stakeholders across the organization a trusted '
#                           'single source of truth.\n'
#                           '\n'
#                           'What You Will Deliver:\n'
#                           '● Architectural Transformation: Design and '
#                           'implement a clean, scalable data modeling layer '
#                           '(e.g., Star Schema, Dimensional Modeling) on top of '
#                           'existing raw SQL databases without disrupting '
#                           'source structures.\n'
#                           '● Business Alignment: Partner closely with business '
#                           'stakeholders to understand their use cases, '
#                           'translating complex business logic into intuitive, '
#                           'well-documented data definitions and models.\n'
#                           '● Data Governance & Lineage: Establish rigorous '
#                           'data governance standards. Maintain clear '
#                           'documentation, define data lineage, and ensure a '
#                           'single source of truth across all business '
#                           'metrics.\n'
#                           '● Data Quality & Testing: Implement automated '
#                           'testing and validation frameworks to ensure data '
#                           'accuracy, reliability, and performance '
#                           'consistency.\n'
#                           '● Performance Optimization: Optimize complex '
#                           'queries, views, and materialized structures within '
#                           'the transformation layer to ensure fast, efficient '
#                           'reporting and analysis.',
#            'description': 'About the Role:\n'
#                           'As a Data Analytics Engineer, you are the strategic '
#                           'link between data engineering and business '
#                           'intelligence at DKSH, owning the design, '
#                           'implementation, and governance of the data '
#                           'transformation architecture that powers reliable, '
#                           'high-performance decision-making. You will convert '
#                           'a complex landscape of raw SQL data sources into a '
#                           'structured, intuitive semantic layer, giving '
#                           'stakeholders across the organization a trusted '
#                           'single source of truth.\n'
#                           '\n'
#                           'What You Will Deliver:\n'
#                           '● Architectural Transformation: Design and '
#                           'implement a clean, scalable data modeling layer '
#                           '(e.g., Star Schema, Dimensional Modeling) on top of '
#                           'existing raw SQL databases without disrupting '
#                           'source structures.\n'
#                           '● Business Alignment: Partner closely with business '
#                           'stakeholders to understand their use cases, '
#                           'translating complex business logic into intuitive, '
#                           'well-documented data definitions and models.\n'
#                           '● Data Governance & Lineage: Establish rigorous '
#                           'data governance standards. Maintain clear '
#                           'documentation, define data lineage, and ensure a '
#                           'single source of truth across all business '
#                           'metrics.\n'
#                           '● Data Quality & Testing: Implement automated '
#                           'testing and validation frameworks to ensure data '
#                           'accuracy, reliability, and performance '
#                           'consistency.\n'
#                           '● Performance Optimization: Optimize complex '
#                           'queries, views, and materialized structures within '
#                           'the transformation layer to ensure fast, efficient '
#                           'reporting and analysis.',
#            'employeeCount': 1300,
#            'hrBehaviorPR': 0.9579757331171578,
#            'interactionRecord': {'lastCustReplyTimestamp': 1785907324,
#                                  'lastProcessedResumeAtTime': 1785900314,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001010,
#            'jobAddrNoDesc': '台北市內湖區',
#            'jobAddress': '堤頂大道二段407巷22號10樓',
#            'jobCat': [2007001018, 2007001022],
#            'jobName': 'Senior Data Analytics Engineer',
#            'jobNameSnippet': 'Senior Data Analytics Engineer',
#            'jobNo': '15257891',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 1,
#            'labels': ['c@wf2',
#                       'c@wf7',
#                       'c@wf9',
#                       'c@wf28',
#                       'association@j00025',
#                       'indexjob@ij009',
#                       'c@wf3',
#                       'c@wf10',
#                       'association@j00021',
#                       'indexjob@ij013',
#                       'c@wf1',
#                       'c@wf35',
#                       'c@wf29',
#                       'association@j00009',
#                       'c@wf12',
#                       'indexjob@ij048',
#                       'foreigners@full_fc_em_jbs',
#                       'c@wf13',
#                       'association@j00002_002',
#                       'association@j00013',
#                       'association@j00017',
#                       'indexjob@ij010',
#                       'c@wf30',
#                       'c@wf26'],
#            'languageRequirements': [],
#            'lat': 25.0811548,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/9312b?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/wjbai6o',
#                     'job': 'https://www.104.com.tw/job/9312b'},
#            'lon': 121.5637103,
#            'major': ['資訊工程相關', '其他數學及電算機科學相關', '其他工程相關'],
#            'mrt': '99001001016',
#            'mrtDesc': '捷運西湖站',
#            'mrtDist': 0.38,
#            'optionEdu': [3, 4, 5],
#            'pcSkills': [{'code': '12001004031', 'description': 'MS SQL'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001004009', 'description': 'Data Modeling'},
#                         {'code': '12003004002',
#                          'description': 'Data Architect'},
#                         {'code': '12001003100',
#                          'description': 'Microsoft Azure'},
#                         {'code': '12001002016', 'description': 'Github'},
#                         {'code': '12001004018', 'description': 'ETL'},
#                         {'code': '12001002018', 'description': 'Git'}],
#            'pddScore': 0.09855294,
#            'period': 6,
#            'remoteWorkType': 2,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'landmark': {'desc': '距捷運西湖站約380公尺'},
#                     'remote': {'desc': '遠端工作'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf12': {'desc': '', 'param': 'wf12'},
#                     'wf13': {'desc': '', 'param': 'wf13'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf28': {'desc': '', 'param': 'wf28'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf30': {'desc': '', 'param': 'wf30'},
#                     'wf35': {'desc': '', 'param': 'wf35'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'zoneForeign': {'desc': '外商公司', 'param': 5}},
#            'userApplyCount': None},
#           {'acceptRole': [],
#            'appearDate': '20260804',
#            'applyCnt': 22,
#            'applyDate': None,
#            'coIndustry': 1004002002,
#            'coIndustryDesc': '證券及期貨業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/5000/27236155000/logo.png?v=20260326133619',
#            'custName': '國泰綜合證券股份有限公司',
#            'custNo': '27236155000',
#            'd3': '',
#            'descSnippet': '及良好職業倫理。\n'
#                           '\n'
#                           '【加分條件】\n'
#                           '1. 具金融業或大型企業人資工作經驗。\n'
#                           '2. 熟悉組織發展、人才發展、人才盤點、績效管理或接班制度。\n'
#                           '3. 具Power BI、Power '
#                           'Query、SQL、[[[Python]]]或其他數據分析工具使用經驗。\n'
#                           '4. 具',
#            'description': '及良好職業倫理。\n'
#                           '\n'
#                           '【加分條件】\n'
#                           '1. 具金融業或大型企業人資工作經驗。\n'
#                           '2. 熟悉組織發展、人才發展、人才盤點、績效管理或接班制度。\n'
#                           '3. 具Power BI、Power Query、SQL、Python或其他數據分析工具使用經驗。\n'
#                           '4. 具',
#            'employeeCount': 1300,
#            'hrBehaviorPR': 0.9172577717467926,
#            'interactionRecord': {'lastCustReplyTimestamp': None,
#                                  'lastProcessedResumeAtTime': 1785894638,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001005,
#            'jobAddrNoDesc': '台北市大安區',
#            'jobAddress': '敦化南路二段335號20樓',
#            'jobCat': [2001002002, 2001002003],
#            'jobName': '資深人力資源專業人員（人力資源部）_I00026637',
#            'jobNameSnippet': '資深人力資源專業人員（人力資源部）_I00026637',
#            'jobNo': '15314139',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 1,
#            'labels': ['association@j00021',
#                       'c@wf1',
#                       'c@wf13',
#                       'c@wf7',
#                       'c@wf31',
#                       'c@wf25',
#                       'c@wf23',
#                       'c@wf30',
#                       'association@j00025',
#                       'c@wf32',
#                       'indexjob@ij009',
#                       'c@wf3',
#                       'association@j00017',
#                       'c@wf2',
#                       'c@wf9',
#                       'c@wf10',
#                       'c@wf28'],
#            'languageRequirements': [{'ability': {'listening': 8,
#                                                  'reading': 8,
#                                                  'speaking': 8,
#                                                  'writing': 8},
#                                      'language': 1}],
#            'lat': 25.0218578,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/948gr?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/cifpbp4',
#                     'job': 'https://www.104.com.tw/job/948gr'},
#            'lon': 121.549381,
#            'major': ['人力資源相關', '一般商業學類', '心理學相關'],
#            'mrt': '99001001007',
#            'mrtDesc': '捷運六張犁站',
#            'mrtDist': 0.44,
#            'optionEdu': [4, 5],
#            'pcSkills': [{'code': '12001008012', 'description': 'PowerPoint'},
#                         {'code': '12001008016', 'description': 'Word'},
#                         {'code': '12001008003', 'description': 'Excel'},
#                         {'code': '12001011012',
#                          'description': 'Power BI\u200b'},
#                         {'code': '12001011001', 'description': 'Tableau'}],
#            'pddScore': 0.100558706,
#            'period': 4,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'landmark': {'desc': '距捷運六張犁站約440公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf13': {'desc': '', 'param': 'wf13'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf23': {'desc': '', 'param': 'wf23'},
#                     'wf25': {'desc': '', 'param': 'wf25'},
#                     'wf28': {'desc': '', 'param': 'wf28'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf30': {'desc': '', 'param': 'wf30'},
#                     'wf31': {'desc': '', 'param': 'wf31'},
#                     'wf32': {'desc': '', 'param': 'wf32'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf9': {'desc': '', 'param': 'wf9'}},
#            'userApplyCount': None},
#           {'acceptRole': [16,
#                           32,
#                           64,
#                           2048,
#                           4096,
#                           8192,
#                           16384,
#                           32768,
#                           65536,
#                           131072],
#            'appearDate': '20260731',
#            'applyCnt': 2,
#            'applyDate': None,
#            'coIndustry': 1008003006,
#            'coIndustryDesc': '其他專業／科學及技術業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/8581/130000000268581/logo.jpg?v=20260616162227',
#            'custName': '新加坡商奎斯特全球工程服務股份有限公司台灣分公司',
#            'custNo': '130000000268581',
#            'd3': '',
#            'descSnippet': '[[[Python]]] Automation Development Engineer\n'
#                           '\n'
#                           '\u2002\u2002\u2002\u2002Role Scope\n'
#                           '\n'
#                           '1.      Support automation and testing activities '
#                           'in lab',
#            'description': 'Python Automation Development Engineer\n'
#                           '\n'
#                           '\u2002\u2002\u2002\u2002Role Scope\n'
#                           '\n'
#                           '1.      Support automation and testing activities '
#                           'in lab',
#            'employeeCount': 22000,
#            'hrBehaviorPR': 0.8763107112646271,
#            'interactionRecord': {'lastCustReplyTimestamp': None,
#                                  'lastProcessedResumeAtTime': 1785898018,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001007,
#            'jobAddrNoDesc': '台北市信義區',
#            'jobAddress': '忠孝東路五段508號12樓',
#            'jobCat': [2007001004, 2007001012, 2007001022],
#            'jobName': 'Python Automation Development Engineer',
#            'jobNameSnippet': '[[[Python]]] Automation Development Engineer',
#            'jobNo': '15320258',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['association@j00001',
#                       'indexjob@ij005',
#                       'foreigners@foreigners_tick',
#                       'c@wf12',
#                       'c@wf29',
#                       'association@j00018',
#                       'c@rdss_welcome',
#                       'indexjob@ij027',
#                       'foreigners@overseasStudents_tick',
#                       'joblist_search@jl_j0003_004.5',
#                       'association@j00031',
#                       'association@j00014',
#                       'indexjob@ij010',
#                       'senior@senior_job_G',
#                       'c@wf8',
#                       'indexjob@ij039',
#                       'association@j00030'],
#            'languageRequirements': [],
#            'lat': 25.0409849,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/94d6q?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bnqjp',
#                     'job': 'https://www.104.com.tw/job/94d6q'},
#            'lon': 121.5786202,
#            'major': [],
#            'mrt': '99001005019',
#            'mrtDesc': '捷運永春站',
#            'mrtDist': 0.26,
#            'optionEdu': [3, 4, 5, 6],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 3.0215535,
#            'period': 5,
#            'remoteWorkType': 0,
#            's10': 60,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 2000000,
#            'salaryLow': 900000,
#            'tags': {'landmark': {'desc': '距捷運永春站約260公尺'},
#                     'wf12': {'desc': '', 'param': 'wf12'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf8': {'desc': '', 'param': 'wf8'}},
#            'userApplyCount': None},
#           {'acceptRole': [],
#            'appearDate': '20260730',
#            'applyCnt': 0,
#            'applyDate': None,
#            'coIndustry': 1009001002,
#            'coIndustryDesc': '人力派遣服務',
#            'custLogo': '',
#            'custName': '皇霖實業股份有限公司',
#            'custNo': '7647004000',
#            'd3': '',
#            'descSnippet': '\n'
#                           ' 3 年以上 [[[Python]]] 後端開發經驗,熟悉 Flask 或其他 '
#                           '[[[Python]]] Web Framework\n'
#                           '(如 Django, FastAPI)。\n'
#                           ' 熟悉 RESTful API 設計 與系統整合。\n'
#                           ' 熟悉 Oracle Database',
#            'description': '\n'
#                           ' 3 年以上 Python 後端開發經驗,熟悉 Flask 或其他 Python Web '
#                           'Framework\n'
#                           '(如 Django, FastAPI)。\n'
#                           ' 熟悉 RESTful API 設計 與系統整合。\n'
#                           ' 熟悉 Oracle Database',
#            'employeeCount': 30,
#            'hrBehaviorPR': 0.06678018821373184,
#            'interactionRecord': {'lastCustReplyTimestamp': 1781490125,
#                                  'lastProcessedResumeAtTime': None,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001007,
#            'jobAddrNoDesc': '台北市信義區',
#            'jobAddress': '',
#            'jobCat': [2007001004],
#            'jobName': 'Python工程師',
#            'jobNameSnippet': '[[[Python]]]工程師',
#            'jobNo': '12116930',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@wf7', 'c@wf3', 'c@wf2'],
#            'languageRequirements': [],
#            'lat': 25.0409201,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/77phe?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/3igtu1s',
#                     'job': 'https://www.104.com.tw/job/77phe'},
#            'lon': 121.5720055,
#            'major': [],
#            'mrt': '',
#            'mrtDesc': '',
#            'mrtDist': 0,
#            'optionEdu': [3, 4, 5],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001004018', 'description': 'ETL'}],
#            'pddScore': 2.2416568,
#            'period': 4,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf7': {'desc': '', 'param': 'wf7'}},
#            'userApplyCount': None},
#           {'acceptRole': [2, 64, 2048],
#            'appearDate': '20260519',
#            'applyCnt': 6,
#            'applyDate': None,
#            'coIndustry': 1001001006,
#            'coIndustryDesc': '其它軟體及網路相關業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/8220/130000000158220/logo.jpg?v=20251021165837',
#            'custName': '學力創意科技股份有限公司',
#            'custNo': '130000000158220',
#            'd3': '',
#            'descSnippet': '-[[[Python]]] 監控與維運系統開發\n'
#                           '-熟悉[[[Python]]]編程語言\n'
#                           '-設計編寫API\n'
#                           '-系統維運\n'
#                           '-技術文件撰寫\n'
#                           '-熟悉AWS\n'
#                           '\n'
#                           '【職務條件】\n'
#                           '-具有 Git 版本控制相關知識\n'
#                           '-熟悉 Linux 基本常見指令\n'
#                           '-可獨立或與團隊合作，工作態度積極、負',
#            'description': '-Python 監控與維運系統開發\n'
#                           '-熟悉Python編程語言\n'
#                           '-設計編寫API\n'
#                           '-系統維運\n'
#                           '-技術文件撰寫\n'
#                           '-熟悉AWS\n'
#                           '\n'
#                           '【職務條件】\n'
#                           '-具有 Git 版本控制相關知識\n'
#                           '-熟悉 Linux 基本常見指令\n'
#                           '-可獨立或與團隊合作，工作態度積極、負',
#            'employeeCount': 10,
#            'hrBehaviorPR': 0.38660254828704355,
#            'interactionRecord': {'lastCustReplyTimestamp': None,
#                                  'lastProcessedResumeAtTime': 1785807470,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001005,
#            'jobAddrNoDesc': '台北市大安區',
#            'jobAddress': '信義路四段55號2樓之1',
#            'jobCat': [2007001004, 2007001007, 2007002005],
#            'jobName': 'Python工程師((Web/APP/IoT開發))',
#            'jobNameSnippet': '[[[Python]]]工程師((Web/APP/IoT開發))',
#            'jobNo': '11896429',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@wf7',
#                       'association@j00014',
#                       'c@wf1',
#                       'c@wf2',
#                       'c@graduates_welcome',
#                       'c@wf26',
#                       'association@j00018',
#                       'indexjob@ij039'],
#            'languageRequirements': [{'ability': {'listening': 8,
#                                                  'reading': 8,
#                                                  'speaking': 8,
#                                                  'writing': 8},
#                                      'language': 1}],
#            'lat': 25.0335405,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/72zcd?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/1a2x6blde4',
#                     'job': 'https://www.104.com.tw/job/72zcd'},
#            'lon': 121.5452738,
#            'major': ['資訊工程相關'],
#            'mrt': '99001001009',
#            'mrtDesc': '捷運大安站',
#            'mrtDist': 0.18,
#            'optionEdu': [1, 2, 3, 4, 5, 6],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 1.9283915,
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 60,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 1000000,
#            'salaryLow': 700000,
#            'tags': {'landmark': {'desc': '距捷運大安站約180公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf7': {'desc': '', 'param': 'wf7'}},
#            'userApplyCount': None},
#           {'acceptRole': [],
#            'appearDate': '20260803',
#            'applyCnt': 4,
#            'applyDate': None,
#            'coIndustry': 1002015001,
#            'coIndustryDesc': '精密儀器相關製造業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/6657/130000000246657/logo.png?v=20260113171616',
#            'custName': '幸瑋科技股份有限公司',
#            'custNo': '130000000246657',
#            'd3': '',
#            'descSnippet': '1.負責自有 IoT 產品的軟體架構設計、功能開發與維護\n'
#                           '2.[[[Python]]] Django 後端框架開發、RESTful API '
#                           '設計、與前端工程師協作開發應用系統\n'
#                           '3.撰寫儀器通訊串接程式，並上傳至雲端服務\n'
#                           '4.架設維護網站於雲端平台\n'
#                           '5.撰寫並',
#            'description': '1.負責自有 IoT 產品的軟體架構設計、功能開發與維護\n'
#                           '2.Python Django 後端框架開發、RESTful API '
#                           '設計、與前端工程師協作開發應用系統\n'
#                           '3.撰寫儀器通訊串接程式，並上傳至雲端服務\n'
#                           '4.架設維護網站於雲端平台\n'
#                           '5.撰寫並',
#            'employeeCount': 70,
#            'hrBehaviorPR': 0.34171013675454676,
#            'interactionRecord': {'lastCustReplyTimestamp': 1783914382,
#                                  'lastProcessedResumeAtTime': 1785830936,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001010,
#            'jobAddrNoDesc': '台北市內湖區',
#            'jobAddress': '瑞光路26巷20弄26號4樓',
#            'jobCat': [2007001015],
#            'jobName': '軟體工程師 (Python)',
#            'jobNameSnippet': '軟體工程師 ([[[Python]]])',
#            'jobNo': '15063433',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@wf12',
#                       'c@wf8',
#                       'c@wf13',
#                       'c@wf26',
#                       'c@wf1',
#                       'indexjob@ij010',
#                       'c@wf29',
#                       'c@wf2',
#                       'indexjob@ij017',
#                       'c@wf10',
#                       'indexjob@ij005',
#                       'c@wf7',
#                       'c@wf9',
#                       'indexjob@ij009'],
#            'languageRequirements': [{'ability': {'listening': 8,
#                                                  'reading': 8,
#                                                  'speaking': 4,
#                                                  'writing': 8},
#                                      'language': 1}],
#            'lat': 25.0700239,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8yv0p?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bn9mp',
#                     'job': 'https://www.104.com.tw/job/8yv0p'},
#            'lon': 121.5821691,
#            'major': ['資訊管理相關', '資訊工程相關'],
#            'mrt': '',
#            'mrtDesc': '',
#            'mrtDist': 0,
#            'optionEdu': [4, 5, 6],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001006043', 'description': 'Django'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001005023', 'description': 'AWS'}],
#            'pddScore': 1.8927382,
#            'period': 3,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf12': {'desc': '', 'param': 'wf12'},
#                     'wf13': {'desc': '', 'param': 'wf13'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf8': {'desc': '', 'param': 'wf8'},
#                     'wf9': {'desc': '', 'param': 'wf9'}},
#            'userApplyCount': None},
#           {'acceptRole': [],
#            'appearDate': '20260805',
#            'applyCnt': 0,
#            'applyDate': None,
#            'coIndustry': 1001005003,
#            'coIndustryDesc': '其他電子零組件相關業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/7975/130000000087975/logo.gif?v=20241029083946',
#            'custName': '艾新科環保材料有限公司',
#            'custNo': '130000000087975',
#            'd3': '09:00-18:00',
#            'descSnippet': ' 熟悉 [[[Python]]] 語言，具備2年以上後端開發經驗\n'
#                           '2. 熟悉 Flask 框架，具備實際專案開發經驗\n'
#                           '3. 熟悉 uWSGI 部署及相關設定\n'
#                           '4. 熟悉 RESTful API 設計與實作\n'
#                           '5. 熟悉 MariaDB、MongoDB 資料庫操作與',
#            'description': ' 熟悉 Python 語言，具備2年以上後端開發經驗\n'
#                           '2. 熟悉 Flask 框架，具備實際專案開發經驗\n'
#                           '3. 熟悉 uWSGI 部署及相關設定\n'
#                           '4. 熟悉 RESTful API 設計與實作\n'
#                           '5. 熟悉 MariaDB、MongoDB 資料庫操作與',
#            'employeeCount': 0,
#            'hrBehaviorPR': 0.99,
#            'interactionRecord': {'lastCustReplyTimestamp': None,
#                                  'lastProcessedResumeAtTime': None,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001007,
#            'jobAddrNoDesc': '台北市信義區',
#            'jobAddress': '基隆路一段163號4樓之2',
#            'jobCat': [2007001004, 2007001016, 2007001017],
#            'jobName': 'Python 後端工程師',
#            'jobNameSnippet': '[[[Python]]] 後端工程師',
#            'jobNo': '15325504',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@wf10',
#                       'c@wf7',
#                       'c@wf1',
#                       'c@wf3',
#                       'association@j00021',
#                       'c@wf29',
#                       'c@wf2'],
#            'languageRequirements': [{'ability': {'listening': 8,
#                                                  'reading': 8,
#                                                  'speaking': 8,
#                                                  'writing': 8},
#                                      'language': 1}],
#            'lat': 25.0418373,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/94h8g?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bjv6v',
#                     'job': 'https://www.104.com.tw/job/94h8g'},
#            'lon': 121.5650477,
#            'major': ['資訊工程相關', '資訊管理相關'],
#            'mrt': '99001005018',
#            'mrtDesc': '捷運市政府站',
#            'mrtDist': 0.15,
#            'optionEdu': [3, 4, 5],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001003080', 'description': 'Go'},
#                         {'code': '12001003095', 'description': 'SaaS'},
#                         {'code': '12001006034', 'description': 'Node.js'},
#                         {'code': '12001006038', 'description': 'VueJS'},
#                         {'code': '12001006037', 'description': 'AngularJS'},
#                         {'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001002016', 'description': 'Github'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001004032', 'description': 'MySQL'}],
#            'pddScore': 1.7549621,
#            'period': 2,
#            'remoteWorkType': 0,
#            's10': 50,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 50000,
#            'salaryLow': 35000,
#            'tags': {'landmark': {'desc': '距捷運市政府站約150公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf7': {'desc': '', 'param': 'wf7'}},
#            'userApplyCount': None},
#           {'acceptRole': [],
#            'appearDate': '20260805',
#            'applyCnt': 2,
#            'applyDate': None,
#            'coIndustry': 1001003001,
#            'coIndustryDesc': '電腦及其週邊設備製造業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/7000/23638777000/logo.jpg?v=20260225120653',
#            'custName': '華碩電腦股份有限公司',
#            'custNo': '23638777000',
#            'd3': '',
#            'descSnippet': '1. Design and implement scalable backend services '
#                           'and high-concurrency APIs using [[[Python]]], '
#                           'including integration with third-',
#            'description': '1. Design and implement scalable backend services '
#                           'and high-concurrency APIs using Python, including '
#                           'integration with third-',
#            'employeeCount': 0,
#            'hrBehaviorPR': 0.21085709502326236,
#            'interactionRecord': {'lastCustReplyTimestamp': None,
#                                  'lastProcessedResumeAtTime': 1785408681,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001009,
#            'jobAddrNoDesc': '台北市北投區',
#            'jobAddress': '',
#            'jobCat': [2007001016, 2007001006],
#            'jobName': 'AD10601 Senior Python Backend Engineer',
#            'jobNameSnippet': 'AD10601 Senior [[[Python]]] Backend Engineer',
#            'jobNo': '12596461',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 2,
#            'labels': ['c@wf1',
#                       'c@wf28',
#                       'c@wf23',
#                       'c@wf13',
#                       'foreigners@full_fc_em_jbs',
#                       'c@wf35',
#                       'c@wf27',
#                       'c@wf34',
#                       'c@wf25',
#                       'c@wf2',
#                       'indexjob@ij009',
#                       'c@wf10',
#                       'c@wf7',
#                       'c@wf30',
#                       'indexjob@ij003',
#                       'indexjob@ij005',
#                       'c@wf8',
#                       'c@wf4',
#                       'c@wf11',
#                       'association@j00002_002',
#                       'foreigners@fc_empmidchinese_jbs',
#                       'indexjob@ij013'],
#            'languageRequirements': [{'ability': {'listening': 8,
#                                                  'reading': 8,
#                                                  'speaking': 8,
#                                                  'writing': 8},
#                                      'language': 1}],
#            'lat': 25.1151759,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/7hzhp?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/auxx12g',
#                     'job': 'https://www.104.com.tw/job/7hzhp'},
#            'lon': 121.515018,
#            'major': ['資訊工程相關', '資訊管理相關'],
#            'mrt': '',
#            'mrtDesc': '',
#            'mrtDist': 0,
#            'optionEdu': [4, 5],
#            'pcSkills': [{'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001004035', 'description': 'Oracle'},
#                         {'code': '12001004039', 'description': 'PostgreSQL'},
#                         {'code': '12001006043', 'description': 'Django'}],
#            'pddScore': 1.6347884,
#            'period': 6,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf11': {'desc': '', 'param': 'wf11'},
#                     'wf13': {'desc': '', 'param': 'wf13'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf23': {'desc': '', 'param': 'wf23'},
#                     'wf25': {'desc': '', 'param': 'wf25'},
#                     'wf27': {'desc': '', 'param': 'wf27'},
#                     'wf28': {'desc': '', 'param': 'wf28'},
#                     'wf30': {'desc': '', 'param': 'wf30'},
#                     'wf34': {'desc': '', 'param': 'wf34'},
#                     'wf35': {'desc': '', 'param': 'wf35'},
#                     'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf8': {'desc': '', 'param': 'wf8'},
#                     'zone': {'desc': '上市上櫃', 'param': 16}},
#            'userApplyCount': None},
#           {'acceptRole': [2, 32, 64],
#            'appearDate': '20260803',
#            'applyCnt': 5,
#            'applyDate': None,
#            'coIndustry': 1001001002,
#            'coIndustryDesc': '電腦軟體服務業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/6000/27571256000/logo.gif?v=20241201233036',
#            'custName': '緯德科技股份有限公司 (TechLink Corporation)',
#            'custNo': '27571256000',
#            'd3': '09:00~18:00',
#            'descSnippet': '- 熟悉[[[Python]]]語言撰寫實務經驗1年以上。\r\n'
#                           '- 可獨立或與團隊合作，工作態度積極、負責，能配合公司規定。\r\n'
#                           '- 依不同經驗及能力來負責系統之分析(SA)、設計(SD)以及程式撰寫(PG)。\r\n'
#                           '- 配合公司專案需求至客戶端駐點服務。',
#            'description': '- 熟悉Python語言撰寫實務經驗1年以上。\r\n'
#                           '- 可獨立或與團隊合作，工作態度積極、負責，能配合公司規定。\r\n'
#                           '- 依不同經驗及能力來負責系統之分析(SA)、設計(SD)以及程式撰寫(PG)。\r\n'
#                           '- 配合公司專案需求至客戶端駐點服務。',
#            'employeeCount': 220,
#            'hrBehaviorPR': 0.4333277527139433,
#            'interactionRecord': {'lastCustReplyTimestamp': 1784194215,
#                                  'lastProcessedResumeAtTime': 1785901342,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001004,
#            'jobAddrNoDesc': '台北市松山區',
#            'jobAddress': '敦化北路207號8F-13',
#            'jobCat': [2007001004, 2007001006, 2007002003],
#            'jobName': 'Python工程師',
#            'jobNameSnippet': '[[[Python]]]工程師',
#            'jobNo': '10505210',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['association@j00008',
#                       'association@j00024',
#                       'c@wf1',
#                       'association@j00001',
#                       'foreigners@foreigners_tick',
#                       'c@wf29',
#                       'c@wf7',
#                       'association@j00021',
#                       'association@j00020',
#                       'c@graduates_welcome',
#                       'c@wf32',
#                       'c@wf9',
#                       'joblist_search@jl_j0003_004.5',
#                       'association@j00014',
#                       'c@wf3'],
#            'languageRequirements': [],
#            'lat': 25.0580023,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/695ve?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/cnz7pa8',
#                     'job': 'https://www.104.com.tw/job/695ve'},
#            'lon': 121.5496155,
#            'major': [],
#            'mrt': '',
#            'mrtDesc': '',
#            'mrtDist': 0,
#            'optionEdu': [3, 4, 5, 6],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 1.5640957,
#            'period': 2,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf32': {'desc': '', 'param': 'wf32'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf9': {'desc': '', 'param': 'wf9'}},
#            'userApplyCount': None},
#           {'acceptRole': [2],
#            'appearDate': '20260803',
#            'applyCnt': 1,
#            'applyDate': None,
#            'coIndustry': 1001001006,
#            'coIndustryDesc': '其它軟體及網路相關業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/7000/24335907000/logo.gif?v=20200730193214',
#            'custName': '碁曄科技股份有限公司',
#            'custNo': '24335907000',
#            'd3': '',
#            'descSnippet': '1. [[[Python]]] Restful API 功能開發\n'
#                           '2. 與前端進行流程對接\n'
#                           '3. 以現有架構進行新功能開發與維運\n'
#                           '4. 閱讀並了解健保法規與技術文件\n',
#            'description': '1. Python Restful API 功能開發\n'
#                           '2. 與前端進行流程對接\n'
#                           '3. 以現有架構進行新功能開發與維運\n'
#                           '4. 閱讀並了解健保法規與技術文件\n',
#            'employeeCount': 0,
#            'hrBehaviorPR': 0.9469459326096151,
#            'interactionRecord': {'lastCustReplyTimestamp': None,
#                                  'lastProcessedResumeAtTime': None,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001005,
#            'jobAddrNoDesc': '台北市大安區',
#            'jobAddress': '仁愛路四段101號4樓之2',
#            'jobCat': [2007001006, 2007001004, 2007001009],
#            'jobName': 'python 後端工程師',
#            'jobNameSnippet': '[[[python]]] 後端工程師',
#            'jobNo': '12641810',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@wf1',
#                       'c@wf29',
#                       'c@wf7',
#                       'c@wf26',
#                       'c@graduates_welcome'],
#            'languageRequirements': [{'ability': {'listening': 8,
#                                                  'reading': 8,
#                                                  'speaking': 8,
#                                                  'writing': 8},
#                                      'language': 1}],
#            'lat': 25.0387291,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/7iyhe?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/b6gyy0o',
#                     'job': 'https://www.104.com.tw/job/7iyhe'},
#            'lon': 121.5483189,
#            'major': ['資訊管理相關', '資訊工程相關'],
#            'mrt': '99001005016',
#            'mrtDesc': '捷運忠孝敦化站',
#            'mrtDist': 0.37,
#            'optionEdu': [4, 5],
#            'pcSkills': [{'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 1.3069643,
#            'period': 3,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'landmark': {'desc': '距捷運忠孝敦化站約370公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf7': {'desc': '', 'param': 'wf7'}},
#            'userApplyCount': None},
#           {'acceptRole': [2],
#            'appearDate': '20260728',
#            'applyCnt': 7,
#            'applyDate': None,
#            'coIndustry': 1006003001,
#            'coIndustryDesc': '廣告行銷公關業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/3134/130000000093134/logo.gif?v=20260609145458',
#            'custName': '烏龜移動科技股份有限公司',
#            'custNo': '130000000093134',
#            'd3': '',
#            'descSnippet': '網路架構及 Web 應用基本知識\n'
#                           '3、能夠撰寫 [[[Python]]] 資料處理腳本或是 Web API\n'
#                           '4、了解 RDBMS 及 NoSQL\n'
#                           '5、良好溝通能力, 能夠與其他團隊協作\n'
#                           '6、分析及解決問題的能力\n'
#                           '7、對程式開發有興趣, 能夠持續學習新知識並應用',
#            'description': '網路架構及 Web 應用基本知識\n'
#                           '3、能夠撰寫 Python 資料處理腳本或是 Web API\n'
#                           '4、了解 RDBMS 及 NoSQL\n'
#                           '5、良好溝通能力, 能夠與其他團隊協作\n'
#                           '6、分析及解決問題的能力\n'
#                           '7、對程式開發有興趣, 能夠持續學習新知識並應用',
#            'employeeCount': 35,
#            'hrBehaviorPR': 0.29403989849147044,
#            'interactionRecord': {'lastCustReplyTimestamp': None,
#                                  'lastProcessedResumeAtTime': 1785403372,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001004,
#            'jobAddrNoDesc': '台北市松山區',
#            'jobAddress': '民權東路三段144號13樓1521室',
#            'jobCat': [2007001004, 2007001006, 2007001012],
#            'jobName': 'Python 軟體工程師',
#            'jobNameSnippet': '[[[Python]]] 軟體工程師',
#            'jobNo': '13306383',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@wf31',
#                       'c@wf7',
#                       'indexjob@ij008',
#                       'c@wf32',
#                       'indexjob@ij014',
#                       'c@wf26',
#                       'c@wf33',
#                       'c@wf29',
#                       'c@wf2',
#                       'c@wf9',
#                       'c@wf12',
#                       'indexjob@ij010',
#                       'c@wf14',
#                       'c@graduates_welcome'],
#            'languageRequirements': [],
#            'lat': 25.0617,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/7x79r?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bjz66',
#                     'job': 'https://www.104.com.tw/job/7x79r'},
#            'lon': 121.5471202,
#            'major': [],
#            'mrt': '99001001012',
#            'mrtDesc': '捷運中山國中站',
#            'mrtDist': 0.31,
#            'optionEdu': [2, 3, 4, 5, 6],
#            'pcSkills': [{'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001002012',
#                          'description': 'Systems Analysis'},
#                         {'code': '12001002013',
#                          'description': 'Systems Analyst'},
#                         {'code': '12001002016', 'description': 'Github'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001004041', 'description': 'RDBMS'},
#                         {'code': '12001005022', 'description': 'hadoop'}],
#            'pddScore': 1.2860777,
#            'period': 2,
#            'remoteWorkType': 0,
#            's10': 50,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 60000,
#            'salaryLow': 40000,
#            'tags': {'landmark': {'desc': '距捷運中山國中站約310公尺'},
#                     'wf12': {'desc': '', 'param': 'wf12'},
#                     'wf14': {'desc': '', 'param': 'wf14'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf31': {'desc': '', 'param': 'wf31'},
#                     'wf32': {'desc': '', 'param': 'wf32'},
#                     'wf33': {'desc': '', 'param': 'wf33'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
# ...
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['indexjob@ij017',
#                       'c@wf26',
#                       'c@wf1',
#                       'c@wf29',
#                       'association@j00002_002',
#                       'c@wf2',
#                       'c@wf10',
#                       'association@j00024',
#                       'indexjob@ij003',
#                       'c@wf7',
#                       'foreigners@full_fc_em_jbs',
#                       'association@j00021',
#                       'c@graduates_welcome',
#                       'c@wf3',
#                       'c@wf4'],
#            'languageRequirements': [{'ability': {'listening': 4,
#                                                  'reading': 8,
#                                                  'speaking': 4,
#                                                  'writing': 4},
#                                      'language': 1}],
#            'lat': 25.0446419,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8osoz?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bjjlo',
#                     'job': 'https://www.104.com.tw/job/8osoz'},
#            'lon': 121.5268064,
#            'major': ['數學及電算機科學學科類', '資訊管理相關'],
#            'mrt': '99001005013',
#            'mrtDesc': '捷運善導寺站',
#            'mrtDist': 0.35,
#            'optionEdu': [4, 5, 6],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 0.9775501,
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 55000,
#            'salaryLow': 40000,
#            'tags': {'landmark': {'desc': '距捷運善導寺站約350公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'zone': {'desc': '上市上櫃', 'param': 16}},
#            'userApplyCount': None},
#           {'acceptRole': [],
#            'appearDate': '20260728',
#            'applyCnt': 9,
#            'applyDate': None,
#            'coIndustry': 1001001002,
#            'coIndustryDesc': '電腦軟體服務業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/6000/53343286000/logo.png?v=20231228101331',
#            'custName': '日新軟體股份有限公司',
#            'custNo': '53343286000',
#            'd3': '09:00~18:00',
#            'descSnippet': 'We are looking for a [[[Python]]] Developer who is '
#                           'capable of developing interactive web pages, '
#                           'backend API servers, web-tracking',
#            'description': 'We are looking for a Python Developer who is '
#                           'capable of developing interactive web pages, '
#                           'backend API servers, web-tracking',
#            'employeeCount': 300,
#            'hrBehaviorPR': 0.9821302692795714,
#            'interactionRecord': {'lastCustReplyTimestamp': 1782884554,
#                                  'lastProcessedResumeAtTime': 1785832341,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001010,
#            'jobAddrNoDesc': '台北市內湖區',
#            'jobAddress': '瑞光路333號16樓',
#            'jobCat': [2007001004],
#            'jobName': 'Software Engineer(Python)',
#            'jobNameSnippet': 'Software Engineer([[[Python]]])',
#            'jobNo': '11684273',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 2,
#            'labels': ['c@wf30',
#                       'c@wf1',
#                       'indexjob@ij009',
#                       'c@wf35',
#                       'c@wf26',
#                       'indexjob@ij013',
#                       'indexjob@ij048',
#                       'indexjob@ij010',
#                       'c@wf34',
#                       'c@wf3',
#                       'c@wf13',
#                       'c@wf7',
#                       'c@wf17',
#                       'c@wf10',
#                       'c@wf2',
#                       'c@wf31',
#                       'c@wf8',
#                       'c@wf12',
#                       'indexjob@ij005',
#                       'c@wf25',
#                       'c@wf9',
#                       'c@wf27',
#                       'indexjob@ij014',
#                       'c@wf29',
#                       'c@wf33'],
#            'languageRequirements': [],
#            'lat': 25.0770622,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/6yfn5?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/oi77qwg',
#                     'job': 'https://www.104.com.tw/job/6yfn5'},
#            'lon': 121.5751213,
#            'major': [],
#            'mrt': '99001001017',
#            'mrtDesc': '捷運港墘站',
#            'mrtDist': 0.34,
#            'optionEdu': [4, 5],
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001006013', 'description': 'HTML'},
#                         {'code': '12001006017', 'description': 'JavaScript'},
#                         {'code': '12001006030', 'description': 'jQuery'},
#                         {'code': '12001006032', 'description': 'CSS'},
#                         {'code': '12001006043', 'description': 'Django'}],
#            'pddScore': 0.94088763,
#            'period': 4,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'landmark': {'desc': '距捷運港墘站約340公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf12': {'desc': '', 'param': 'wf12'},
#                     'wf13': {'desc': '', 'param': 'wf13'},
#                     'wf17': {'desc': '', 'param': 'wf17'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf25': {'desc': '', 'param': 'wf25'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf27': {'desc': '', 'param': 'wf27'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf30': {'desc': '', 'param': 'wf30'},
#                     'wf31': {'desc': '', 'param': 'wf31'},
#                     'wf33': {'desc': '', 'param': 'wf33'},
#                     'wf34': {'desc': '', 'param': 'wf34'},
#                     'wf35': {'desc': '', 'param': 'wf35'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf8': {'desc': '', 'param': 'wf8'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'zoneForeign': {'desc': '外商公司', 'param': 5}},
#            'userApplyCount': None},
#           {'acceptRole': [2, 1024, 65536],
#            'appearDate': '20260730',
#            'applyCnt': 7,
#            'applyDate': None,
#            'coIndustry': 1001001002,
#            'coIndustryDesc': '電腦軟體服務業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/6000/27535576000/logo.png?v=20260106222637',
#            'custName': '樂倍達數位科技股份有限公司',
#            'custNo': '27535576000',
#            'd3': '',
#            'descSnippet': '【工作內容】:\n'
#                           '1. AI技術研究與服務系統應用與串接研究\n'
#                           '2. AI應用服務系統開發，以及周邊服務系統整合\n'
#                           '\n'
#                           '【必備條件】:\n'
#                           '1. 熟AI服務應用\n'
#                           '2. 熟[[[Python]]]開發語言及LLM訓練方法，不排斥接觸不同的開發語言\n'
#                           '3. 具 SVN、Git',
#            'description': '【工作內容】:\n'
#                           '1. AI技術研究與服務系統應用與串接研究\n'
#                           '2. AI應用服務系統開發，以及周邊服務系統整合\n'
#                           '\n'
#                           '【必備條件】:\n'
#                           '1. 熟AI服務應用\n'
#                           '2. 熟Python開發語言及LLM訓練方法，不排斥接觸不同的開發語言\n'
#                           '3. 具 SVN、Git',
#            'employeeCount': 20,
#            'hrBehaviorPR': 0.588134868884816,
#            'interactionRecord': {'lastCustReplyTimestamp': 1783394579,
#                                  'lastProcessedResumeAtTime': 1785834775,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001003,
#            'jobAddrNoDesc': '台北市中山區',
#            'jobAddress': '中山北路三段45號8樓',
#            'jobCat': [2007001020, 2007001022, 2007001004],
#            'jobName': 'Python研發工程師',
#            'jobNameSnippet': '[[[Python]]]研發工程師',
#            'jobNo': '14988156',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@graduates_welcome',
#                       'indexjob@ij003',
#                       'c@wf31',
#                       'indexjob@ij026',
#                       'c@wf29',
#                       'foreigners@overseasStudents_tick',
#                       'c@wf1',
#                       'c@wf26',
#                       'c@intern_welcome',
#                       'association@j00001',
#                       'c@wf4'],
#            'languageRequirements': [],
#            'lat': 25.0662711,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8x8xo?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/cndyyf4',
#                     'job': 'https://www.104.com.tw/job/8x8xo'},
#            'lon': 121.5225901,
#            'major': [],
#            'mrt': '99001002012',
#            'mrtDesc': '捷運民權西路站',
#            'mrtDist': 0.47,
#            'optionEdu': [4, 5, 6],
#            'pcSkills': [{'code': '12001006027', 'description': 'XML'},
#                         {'code': '12001004032', 'description': 'MySQL'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001004039', 'description': 'PostgreSQL'},
#                         {'code': '12001003097', 'description': 'LLM'},
#                         {'code': '12001004041', 'description': 'RDBMS'},
#                         {'code': '12001003088', 'description': 'NLP'},
#                         {'code': '12001002016', 'description': 'Github'},
#                         {'code': '12001003086', 'description': 'PyTorch'},
#                         {'code': '12001003087', 'description': 'tensorflow'},
#                         {'code': '12001001020', 'description': 'Shell'},
#                         {'code': '12001006017', 'description': 'JavaScript'},
#                         {'code': '12001003099', 'description': 'Prompt'}],
#            'pddScore': 0.8811603,
#            'period': 2,
#            'remoteWorkType': 0,
#            's10': 10,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'landmark': {'desc': '距捷運民權西路站約470公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf31': {'desc': '', 'param': 'wf31'},
#                     'wf4': {'desc': '', 'param': 'wf4'}},
#            'userApplyCount': None},
#           {'acceptRole': [],
#            'appearDate': '20260730',
#            'applyCnt': 11,
#            'applyDate': None,
#            'coIndustry': 1001001006,
#            'coIndustryDesc': '其它軟體及網路相關業',
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/2000/80682392000/logo.png?v=20250416150709',
#            'custName': '悟空科技股份有限公司',
#            'custNo': '80682392000',
#            'd3': '平日9:00-17:00',
#            'descSnippet': '-具[[[Python]]]使用經驗\n'
#                           '-具PyTorch 使用經驗\n'
#                           '-具Git 與 CI/CD 流程（GitLab CI、GitHub Actions）使用經驗\n'
#                           '-具獨立研究開源程式碼相關經驗\n'
#                           '-具Linux環境、Docker、Anaconda、GCP等相關',
#            'description': '-具Python使用經驗\n'
#                           '-具PyTorch 使用經驗\n'
#                           '-具Git 與 CI/CD 流程（GitLab CI、GitHub Actions）使用經驗\n'
#                           '-具獨立研究開源程式碼相關經驗\n'
#                           '-具Linux環境、Docker、Anaconda、GCP等相關',
#            'employeeCount': 10,
#            'hrBehaviorPR': 0.9405509833638799,
#            'interactionRecord': {'lastCustReplyTimestamp': 1785894514,
#                                  'lastProcessedResumeAtTime': 1785894552,
#                                  'nowTimestamp': 1785907736},
#            'isApplied': None,
#            'isSave': None,
#            'jobAddrNo': 6001001003,
#            'jobAddrNoDesc': '台北市中山區',
#            'jobAddress': '建國北路一段90號5樓之3(丙園金融大樓）',
#            'jobCat': [2007001020, 2007001012, 2007001022],
#            'jobName': 'AI工程師Python',
#            'jobNameSnippet': 'AI工程師[[[Python]]]',
#            'jobNo': '14882908',
#            'jobRo': 1,
#            'jobSwitch': 'on',
#            'jobType': 0,
#            'labels': ['c@wf7',
#                       'c@wf10',
#                       'c@wf18',
#                       'c@wf1',
#                       'indexjob@ij039',
#                       'association@j00020',
#                       'indexjob@ij017',
#                       'association@j00021'],
#            'languageRequirements': [],
#            'lat': 25.0500012,
#            'link': {'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8uzq4?channel=104rpt',
#                     'cust': 'https://www.104.com.tw/company/112c7o3k',
#                     'job': 'https://www.104.com.tw/job/8uzq4'},
#            'lon': 121.5362706,
#            'major': [],
#            'mrt': '99001003016',
#            'mrtDesc': '捷運松江南京站',
#            'mrtDist': 0.4,
#            'optionEdu': [4, 5, 6],
#            'pcSkills': [{'code': '12001002016', 'description': 'Github'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001003086', 'description': 'PyTorch'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001001007', 'description': 'Linux'}],
#            'pddScore': 0.8498013,
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            's5': 0,
#            's9': [1],
#            'salaryHigh': 9999999,
#            'salaryLow': 45000,
#            'tags': {'landmark': {'desc': '距捷運松江南京站約400公尺'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf18': {'desc': '', 'param': 'wf18'},
#                     'wf7': {'desc': '', 'param': 'wf7'}},
#            'userApplyCount': None}],
#  'metadata': {'filterQuery': {'area': ['6001001000'],
#                               'asc': 0,
#                               'enableJobNoTopOrder': 1,
#                               'excludeKwFz': 4,
#                               'excludeKwKwop': 8,
#                               'fz': 8,
#                               'keyword': 'python',
#                               'kwop': 7,
#                               'order': 15,
#                               'page': 1,
#                               'pagesize': 20,
#                               'ro': [0],
#                               'scneg': 0,
#                               'scstrict': 0},
#               'isPreciseHotJob': False,
#               'offJobs': [],
#               'pagination': {'count': 22,
#                              'currentPage': 1,
#                              'lastPage': 150,
#                              'total': 3587},
#               'personalBoost': 0}}

# %%
#area?kw=6001001000 (台北市)

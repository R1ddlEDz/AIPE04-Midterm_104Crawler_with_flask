# %%
import requests
from bs4 import BeautifulSoup as bs
import re
custom_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Safari/537.36",
}

url = r'https://www.104.com.tw/jobs/search/?jobsource=joblist_search&keyword=Python+%E8%BB%9F%E9%AB%94%E5%B7%A5%E7%A8%8B%E5%B8%AB&mode=s&page=1&area=6001001000&order=15'
res = requests.get(url,headers=custom_headers)
kw=""
key_word = f'{kw}='
print(res.status_code)
soup = bs(res.text, 'lxml')
print(soup)
# Out:
# 200
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head>
# <!-- utility -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, viewport-fit=cover" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.104.com.tw/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.104.com.tw/favicon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <!-- dns prefetch -->
# <link href="https://cdn.104.com.tw/" rel="dns-prefetch"/>
# <link href="https://heybar.an9.104.com.tw/" rel="dns-prefetch"/>
# <link href="https://static.104.com.tw/" rel="dns-prefetch"/>
# <title>ææ°æ¾å·¥ä½è·ç¼ºï¼104äººåéè¡</title>
# <!-- category picker -->
# <link href="//cdn.104.com.tw/category-tool/3.0.2/css/category-picker.css" nonce="82826f28ea693e2694cd1d508bece978" rel="stylesheet" type="text/css"/>
# ...

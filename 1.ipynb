# %%
import requests
from bs4 import BeautifulSoup as bs
import re
from pprint import pprint

custom_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Safari/537.36",
    "Referer" : "https://104.com.tw"
}

query = ''

params = {
    "ro" : "1", #0全部職缺 1正2兼
    "keyword" : "python", #關鍵字
    "area" : "6001001000", #地區(台北市)
    "jobexp" : "1" #工作經驗 1年以下
}

#url = f'https://www.104.com.tw/jobs/search/api/jobs?area={area}&jobsource=index_s&keyword={key_word}&mode=s&order=15&page=1&pagesize=20{job_exp}'
url = "https://www.104.com.tw/jobs/search/api/jobs?"
res = requests.get(url,headers=custom_headers,params=params)



print(res.status_code)

job_id_list = []
data = res.json()

for item in data['data']:
    job_id_list.append(item['link']['job'][-5:])
    
pprint(data, sort_dicts=False)
print(job_id_list)
# Out:
# 200
# {'data': [{'appearDate': '20260721',
#            'applyCnt': 2,
#            'coIndustry': 1016002001,
#            'coIndustryDesc': '餐館業',
#            'custName': '台灣壽司郎股份有限公司',
#            'custNo': '130000000104300',
#            'description': '⭕工作內容\n'
#                           '．店鋪系統維運：故障對應、網路環境偵錯、系統問題諮詢回覆、新開店系統架設。\n'
#                           '．總部系統維運：總部設備故障對應、系統問題諮詢回覆。\n'
#                           '．供應商管理：設備採購、供應商調派。\n'
#                           '．專案管理：新系統導入，既存系統優化。需整合既有系統狀況並規劃新系統架構。\n'
#                           '．跨部門溝通： 協調各部門協助系統導入。\n'
#                           '．假日需排班或加班支援，需oncall。\n'
#                           '．需出差。\n'
#                           '．需要細心、可自主學習、誠實的人。\n'
#                           '\n'
#                           '⭕職經歷要求：\n'
#                           '．（非必要）需有餐飲業、流通業、零售業相關經驗兩年\n'
#                           '．（非必要）需有擔任MIS人員的經驗兩年\n'
#                           '．（非必要）需有擔任專案經理職務的經驗兩年\n'
#                           '．（非必要）AWS / Azure 等雲端平台操作與維護經驗者\n'
#                           '．（非必要）ISO 27001 資安認證概念或相關操作經驗者。\n'
#                           '\n'
#                           '⭕必要條件\n'
#                           '▪日文能力（N2以上）\n'
#                           '\n'
#                           '⭕獎金福利\n'
#                           '【夏、冬季獎金】一年發放兩次(金額依公司營運狀況及職等考核調整)\n'
#                           '【三節獎金】\n'
#                           '【春酒抽獎】\n'
#                           '【津貼禮券】:結婚生育津貼、喪葬慰問金、生日禮券、全勤禮券\n'
#                           '【其他福利】:在職進修、每月慶生活動\n'
#                           '\n'
#                           '⭕企業魅力\n'
#                           '▪「以人為本」注重團隊合作及交流，採納同仁的意見，提升參與感\n'
#                           '▪升遷快速且制度完善，依努力及成果將有升遷加薪的機會\n'
#                           '▪享有完善的福利制度，加班費為5分鐘為單位計算，重視員工的辛勤付出\n'
#                           '▪計畫拓展全台灣，讓更多人有機會品嚐美味平價壽司，致力成為頂尖品牌',
#            'descSnippet': '⭕工作內容\n'
#                           '．店鋪系統維運：故障對應、網路環境偵錯、系統問題諮詢回覆、新開店系統架設。\n'
#                           '．總部系統維運：總部設備故障對應、系統問題諮詢回覆。\n'
#                           '．供應商管理：設備採購、供應商調派。\n'
#                           '．專案管理：新系統導入，既存系統優化。需整合既有系統狀況並規劃新系統架構。\n'
#                           '．跨部門溝通： 協調各部門協助系統導入。\n'
#                           '．假日需排班或加班支援，需oncall。\n'
#                           '．需出差。\n'
#                           '．需要細心、可自主學習、誠實的人。\n'
#                           '\n'
#                           '⭕職經歷要求：\n'
#                           '．（非必要）需有餐飲業、流通業、零售業相關經驗兩年\n'
#                           '．（非必要）需有擔任MIS人員的經驗兩年\n'
#                           '．（非必要）需有擔任專案經理職務的經驗兩年\n'
#                           '．（非必要）AWS / Azure 等雲端平台操作與維護經驗者\n'
#                           '．（非必要）ISO 27001 資安認證概念或相關操作經驗者。\n'
#                           '\n'
#                           '⭕必要條件\n'
#                           '▪日文能力（N2以上）\n'
#                           '\n'
#                           '⭕獎金福利\n'
#                           '【夏、冬季獎金】一年發放兩次(金額依公司營運狀況及職等考核調整)\n'
#                           '【三節獎金】\n'
#                           '【春酒抽獎】\n'
#                           '【津貼禮券】:結婚生育津貼、喪葬慰問金、生日禮券、全勤禮券\n'
#                           '【其他福利】:在職進修、每月慶生活動\n'
#                           '\n'
#                           '⭕企業魅力\n'
#                           '▪「以人為本」注重團隊合作及交流，採納同仁的意見，提升參與感\n'
#                           '▪升遷快速且制度完善，依努力及成果將有升遷加薪的機會\n'
#                           '▪享有完善的福利制度，加班費為5分鐘為單位計算，重視員工的辛勤付出\n'
#                           '▪計畫拓展全台灣，讓更多人有機會品嚐美味平價壽司，致力成為頂尖品牌',
#            'mrtDist': 0.37,
#            'jobAddress': '松江路61-1號3樓',
#            'jobAddrNo': 6001001003,
#            'jobAddrNoDesc': '台北市中山區',
#            'jobName': '資訊部助理/專員/組長',
#            'jobNameSnippet': '資訊部助理/專員/組長',
#            'jobNo': '15258042',
#            'jobRo': 1,
#            'jobType': 1,
#            'lat': 25.0487401,
#            'lon': 121.5331631,
#            'link': {'job': 'https://www.104.com.tw/job/9316i',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bk7sc',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/9316i?channel=104rpt'},
#            'major': [],
#            'mrt': '99001003016',
#            'mrtDesc': '捷運松江南京站',
#            'optionEdu': [4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            'salaryHigh': 50000,
#            'salaryLow': 36000,
#            'tags': {'zoneForeign': {'desc': '外商公司', 'param': 5},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf17': {'desc': '', 'param': 'wf17'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf16': {'desc': '', 'param': 'wf16'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf14': {'desc': '', 'param': 'wf14'},
#                     'wf20': {'desc': '', 'param': 'wf20'},
#                     'landmark': {'desc': '距捷運松江南京站約370公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.7875240243076,
#            'jobCat': [2007002006, 2007002005, 2007002002],
#            'labels': ['foreigners@fc_emp5m_jbs',
#                       'association@j00009',
#                       'foreigners@full_fc_em_jbs',
#                       'c@wf2',
#                       'joblist_search@jl_j0003_004.5',
#                       'c@rdss_welcome',
#                       'association@j00026',
#                       'c@wf17',
#                       'association@j00021',
#                       'foreigners@pt_fc_em_jbs',
#                       'association@j00030',
#                       'c@wf7',
#                       'association@j00025',
#                       'c@wf16',
#                       'c@graduates_welcome',
#                       'association@j00018',
#                       'association@j00013',
#                       'association@j00014',
#                       'c@graduates_keyword',
#                       'c@2026career',
#                       'c@wf9',
#                       'c@wf14',
#                       'foreigners@foreigners_tick',
#                       'association@j00002_002',
#                       'association@j00022',
#                       'c@graduates_welcome_keyword',
#                       'indexjob@ij008',
#                       'c@wf20',
#                       'indexjob@ij006',
#                       'indexjob@ij020',
#                       'c@intern_welcome',
#                       'senior@senior_job_A',
#                       'indexjob@ij048',
#                       'association@j00017',
#                       'association@j00031',
#                       'foreigners@overseasStudents_tick',
#                       'association@j00029'],
#            'languageRequirements': [{'language': 2,
#                                      'ability': {'listening': 8,
#                                                  'speaking': 8,
#                                                  'reading': 8,
#                                                  'writing': 8}}],
#            'acceptRole': [2,
#                           4,
#                           8,
#                           16,
#                           32,
#                           64,
#                           1024,
#                           2048,
#                           4096,
#                           8192,
#                           16384,
#                           32768,
#                           65536,
#                           131072],
#            'employeeCount': 4200,
#            'pcSkills': [],
#            'pddScore': 0.113256216,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/4300/130000000104300/logo.jpg?v=20260701123519',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786116360,
#                                  'lastCustReplyTimestamp': 1785727604,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260519',
#            'applyCnt': 6,
#            'coIndustry': 1001001006,
#            'coIndustryDesc': '其它軟體及網路相關業',
#            'custName': '學力創意科技股份有限公司',
#            'custNo': '130000000158220',
#            'description': '-Python 監控與維運系統開發\n'
#                           '-熟悉Python編程語言\n'
#                           '-設計編寫API\n'
#                           '-系統維運\n'
#                           '-技術文件撰寫\n'
#                           '-熟悉AWS\n'
#                           '\n'
#                           '【職務條件】\n'
#                           '-具有 Git 版本控制相關知識\n'
#                           '-熟悉 Linux 基本常見指令\n'
#                           '-可獨立或與團隊合作，工作態度積極、負',
#            'descSnippet': '-[[[Python]]] 監控與維運系統開發\n'
#                           '-熟悉[[[Python]]]編程語言\n'
#                           '-設計編寫API\n'
#                           '-系統維運\n'
#                           '-技術文件撰寫\n'
#                           '-熟悉AWS\n'
#                           '\n'
#                           '【職務條件】\n'
#                           '-具有 Git 版本控制相關知識\n'
#                           '-熟悉 Linux 基本常見指令\n'
#                           '-可獨立或與團隊合作，工作態度積極、負',
#            'mrtDist': 0.18,
#            'jobAddress': '信義路四段55號2樓之1',
#            'jobAddrNo': 6001001005,
#            'jobAddrNoDesc': '台北市大安區',
#            'jobName': 'Python工程師((Web/APP/IoT開發))',
#            'jobNameSnippet': '[[[Python]]]工程師((Web/APP/IoT開發))',
#            'jobNo': '11896429',
#            'jobRo': 1,
#            'jobType': 0,
#            'lat': 25.0335405,
#            'lon': 121.5452738,
#            'link': {'job': 'https://www.104.com.tw/job/72zcd',
#                     'cust': 'https://www.104.com.tw/company/1a2x6blde4',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/72zcd?channel=104rpt'},
#            'major': ['資訊工程相關'],
#            'mrt': '99001001009',
#            'mrtDesc': '捷運大安站',
#            'optionEdu': [1, 2, 3, 4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 60,
#            'salaryHigh': 1000000,
#            'salaryLow': 700000,
#            'tags': {'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'landmark': {'desc': '距捷運大安站約180公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.34973392732160913,
#            'jobCat': [2007001004, 2007001007, 2007002005],
#            'labels': ['c@wf7',
#                       'association@j00014',
#                       'c@wf2',
#                       'c@graduates_welcome',
#                       'c@wf26',
#                       'association@j00018',
#                       'indexjob@ij039',
#                       'c@wf1'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 8,
#                                                  'speaking': 8,
#                                                  'reading': 8,
#                                                  'writing': 8}}],
#            'acceptRole': [2, 64, 2048],
#            'employeeCount': 10,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 1.8992765,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/8220/130000000158220/logo.jpg?v=20251021165837',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1785918389,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260803',
#            'applyCnt': 5,
#            'coIndustry': 1001001002,
#            'coIndustryDesc': '電腦軟體服務業',
#            'custName': '艾帝浦杰股份有限公司',
#            'custNo': '130000000041876',
#            'description': '【技術需求】\n'
#                           'Python 開發經驗 2 年以上\n'
#                           '熟悉 pandas、openpyxl、xlsxwriter 及 pymupdf、tabula 等 '
#                           'Python 文件處理套件\n'
#                           '熟悉 selenium、playwright 等 Python 瀏覽器',
#            'descSnippet': '【技術需求】\n'
#                           '[[[Python]]] 開發經驗 2 年以上\n'
#                           '熟悉 pandas、openpyxl、xlsxwriter 及 pymupdf、tabula 等 '
#                           '[[[Python]]] 文件處理套件\n'
#                           '熟悉 selenium、playwright 等 [[[Python]]] 瀏覽器',
#            'mrtDist': 0,
#            'jobAddress': '',
#            'jobAddrNo': 6001001011,
#            'jobAddrNoDesc': '台北市南港區',
#            'jobName': 'Python程式設計師(PG)(臺北市南港區)',
#            'jobNameSnippet': '[[[Python]]]程式設計師(PG)(臺北市南港區)',
#            'jobNo': '15114029',
#            'jobRo': 1,
#            'jobType': 2,
#            'lat': 25.0312347,
#            'lon': 121.6111949,
#            'link': {'job': 'https://www.104.com.tw/job/8zy25',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bivmc',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8zy25?channel=104rpt'},
#            'major': [],
#            'mrt': '',
#            'mrtDesc': '',
#            'optionEdu': [1, 2, 3, 4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            'salaryHigh': 65000,
#            'salaryLow': 55000,
#            'tags': {'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf31': {'desc': '', 'param': 'wf31'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf8': {'desc': '', 'param': 'wf8'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf7': {'desc': '', 'param': 'wf7'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.4286403075111373,
#            'jobCat': [2007001004],
#            'labels': ['association@j00009',
#                       'joblist_search@jl_j0003_004.5',
#                       'senior@senior_job_G',
#                       'indexjob@ij039',
#                       'association@j00026',
#                       'c@wf4',
#                       'association@j00021',
#                       'association@j00030',
#                       'foreigners@overseasStudents_tick',
#                       'c@wf2',
#                       'foreigners@foreigners_tick',
#                       'indexjob@ij005',
#                       'indexjob@ij003',
#                       'association@j00001',
#                       'c@wf31',
#                       'association@j00018',
#                       'c@wf10',
#                       'foreigners@fc_emp5m_jbs',
#                       'c@wf8',
#                       'c@wf1',
#                       'c@wf7',
#                       'association@j00014'],
#            'languageRequirements': [],
#            'acceptRole': [8, 32, 64, 2048, 4096, 32768, 65536, 131072],
#            'employeeCount': 60,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 1.0830582,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/1876/130000000041876/logo.png?v=20260401170349',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786016638,
#                                  'lastCustReplyTimestamp': 1783574450,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260803',
#            'applyCnt': 7,
#            'coIndustry': 1001001003,
#            'coIndustryDesc': '網際網路相關業',
#            'custName': '意藍資訊股份有限公司',
#            'custNo': '130000000072956',
#            'description': '本公司是國內搜尋及語意分析市占率最高的廠商，專注研發非結構資料之數據處理，尋找熟悉Python及物件導向設計的人才加入。工作主要為開發與維運資料產線，搜集語料、資料儲存處理，並提供API服務供下游服務使用。\n'
#                           '\n'
#                           '工作內容如下：\n'
#                           '- 資料搜集程式開發',
#            'descSnippet': '本公司是國內搜尋及語意分析市占率最高的廠商，專注研發非結構資料之數據處理，尋找熟悉[[[Python]]]及物件導向設計的人才加入。工作主要為開發與維運資料產線，搜集語料、資料儲存處理，並提供API服務供下游服務使用。\n'
#                           '\n'
#                           '工作內容如下：\n'
#                           '- 資料搜集程式開發',
#            'mrtDist': 0.35,
#            'jobAddress': '杭州北路26號12樓 (新光華山金融中心)',
#            'jobAddrNo': 6001001001,
#            'jobAddrNoDesc': '台北市中正區',
#            'jobName': 'P7-Python資料工程師',
#            'jobNameSnippet': 'P7-[[[Python]]]資料工程師',
#            'jobNo': '12354332',
#            'jobRo': 1,
#            'jobType': 0,
#            'lat': 25.0446419,
#            'lon': 121.5268064,
#            'link': {'job': 'https://www.104.com.tw/job/7csnw',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bjjlo',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/7csnw?channel=104rpt'},
#            'major': ['數學及電算機科學學科類', '資訊管理相關'],
#            'mrt': '99001005013',
#            'mrtDesc': '捷運善導寺站',
#            'optionEdu': [4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            'salaryHigh': 45000,
#            'salaryLow': 35000,
#            'tags': {'zone': {'desc': '上市上櫃', 'param': 16},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'landmark': {'desc': '距捷運善導寺站約350公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.5583571261928832,
#            'jobCat': [2007001004, 2007001012, 2007001006],
#            'labels': ['c@wf7',
#                       'foreigners@full_fc_em_jbs',
#                       'c@wf3',
#                       'c@wf29',
#                       'association@j00002_002',
#                       'association@j00021',
#                       'c@wf26',
#                       'c@wf10',
#                       'c@graduates_welcome',
#                       'c@wf4',
#                       'c@wf2',
#                       'c@wf1',
#                       'indexjob@ij003'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 4,
#                                                  'speaking': 4,
#                                                  'reading': 8,
#                                                  'writing': 4}}],
#            'acceptRole': [2],
#            'employeeCount': 114,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 0.8256687,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/2956/130000000072956/logo.png?v=20260127111113',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786096161,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260803',
#            'applyCnt': 9,
#            'coIndustry': 1001001003,
#            'coIndustryDesc': '網際網路相關業',
#            'custName': '意藍資訊股份有限公司',
#            'custNo': '130000000072956',
#            'description': '我們是國內領先的雲端智能數據分析公司，專注於AI 及數據應用技術，誠摯邀請對智能數據 (Data '
#                           'Intelligence) 充滿熱情的你，一同開拓未來！\n'
#                           '\n'
#                           '我們正在尋找具備實務經驗與獨立問題解決能力的 Python 工程師加入團隊。\n'
#                           '\n'
#                           '我們理解',
#            'descSnippet': '我們是國內領先的雲端智能數據分析公司，專注於AI 及數據應用技術，誠摯邀請對智能數據 (Data '
#                           'Intelligence) 充滿熱情的你，一同開拓未來！\n'
#                           '\n'
#                           '我們正在尋找具備實務經驗與獨立問題解決能力的 [[[Python]]] 工程師加入團隊。\n'
#                           '\n'
#                           '我們理解',
#            'mrtDist': 0.35,
#            'jobAddress': '杭州北路26號12樓 (新光華山金融中心)',
#            'jobAddrNo': 6001001001,
#            'jobAddrNoDesc': '台北市中正區',
#            'jobName': 'P10-Python應用工程師',
#            'jobNameSnippet': 'P10-[[[Python]]]應用工程師',
#            'jobNo': '14593859',
#            'jobRo': 1,
#            'jobType': 0,
#            'lat': 25.0446419,
#            'lon': 121.5268064,
#            'link': {'job': 'https://www.104.com.tw/job/8osoz',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bjjlo',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8osoz?channel=104rpt'},
#            'major': ['數學及電算機科學學科類', '資訊管理相關'],
#            'mrt': '99001005013',
#            'mrtDesc': '捷運善導寺站',
#            'optionEdu': [4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            'salaryHigh': 55000,
#            'salaryLow': 40000,
#            'tags': {'zone': {'desc': '上市上櫃', 'param': 16},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'landmark': {'desc': '距捷運善導寺站約350公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.3957072867252508,
#            'jobCat': [2007001004, 2007001012, 2007001006],
#            'labels': ['indexjob@ij017',
#                       'c@wf26',
#                       'c@wf1',
#                       'c@wf29',
#                       'association@j00002_002',
#                       'c@wf2',
#                       'c@graduates_welcome',
#                       'c@wf3',
#                       'c@wf4',
#                       'c@wf10',
#                       'association@j00024',
#                       'indexjob@ij003',
#                       'c@wf7',
#                       'foreigners@full_fc_em_jbs',
#                       'association@j00021'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 4,
#                                                  'speaking': 4,
#                                                  'reading': 8,
#                                                  'writing': 4}}],
#            'acceptRole': [2],
#            'employeeCount': 114,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 0.7689862,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/2956/130000000072956/logo.png?v=20260127111113',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786090466,
#                                  'lastCustReplyTimestamp': 1781658447,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260804',
#            'applyCnt': 13,
#            'coIndustry': 1001002001,
#            'coIndustryDesc': '電信相關業',
#            'custName': '台灣大哥大股份有限公司',
#            'custNo': '97176270000',
#            'description': '給自己也給我們一個機會，加入我們一同持續精進IT專業技術，改寫自己的人生與改寫世界，讓我們一起變得更好，歡迎登艦！\n'
#                           '\n'
#                           '【工作內容】\n'
#                           '1. Python Web Application開發(Flask + jQuery單體架構 或 '
#                           'FastAPI +',
#            'descSnippet': '給自己也給我們一個機會，加入我們一同持續精進IT專業技術，改寫自己的人生與改寫世界，讓我們一起變得更好，歡迎登艦！\n'
#                           '\n'
#                           '【工作內容】\n'
#                           '1. [[[Python]]] Web Application開發(Flask + '
#                           'jQuery單體架構 或 FastAPI +',
#            'mrtDist': 0,
#            'jobAddress': '',
#            'jobAddrNo': 6001001005,
#            'jobAddrNoDesc': '台北市大安區',
#            'jobName': 'I105 Python Web工程師(可遠端工作)',
#            'jobNameSnippet': 'I105 [[[Python]]] Web工程師(可遠端工作)',
#            'jobNo': '14277849',
#            'jobRo': 1,
#            'jobType': 2,
#            'lat': 25.0249441,
#            'lon': 121.5433783,
#            'link': {'job': 'https://www.104.com.tw/job/8i0ux',
#                     'cust': 'https://www.104.com.tw/company/18n48ptc',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8i0ux?channel=104rpt'},
#            'major': [],
#            'mrt': '',
#            'mrtDesc': '',
#            'optionEdu': [1, 2, 3, 4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 2,
#            's10': 10,
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'zone': {'desc': '上市上櫃', 'param': 16},
#                     'remote': {'desc': '遠端工作'},
#                     'wf30': {'desc': '', 'param': 'wf30'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf33': {'desc': '', 'param': 'wf33'},
#                     'wf25': {'desc': '', 'param': 'wf25'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf13': {'desc': '', 'param': 'wf13'},
#                     'wf28': {'desc': '', 'param': 'wf28'},
#                     'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf35': {'desc': '', 'param': 'wf35'},
#                     'wf8': {'desc': '', 'param': 'wf8'},
#                     'wf31': {'desc': '', 'param': 'wf31'},
#                     'wf1': {'desc': '', 'param': 'wf1'}},
#            's9': [1],
#            's5': 0,
#            'd3': '可彈性選擇上班時段',
#            'hrBehaviorPR': 0.7010631797629231,
#            'jobCat': [2007001004],
#            'labels': ['indexjob@ij014',
#                       'c@wf30',
#                       'foreigners@pt_fc_em_jbs',
#                       'c@wf10',
#                       'indexjob@ij023',
#                       'c@wf33',
#                       'indexjob@ij016',
#                       'c@wf25',
#                       'c@wf7',
#                       'c@wf4',
#                       'indexjob@ij009',
#                       'c@wf26',
#                       'indexjob@ij005',
#                       'c@wf9',
#                       'association@j00002_002',
#                       'c@wf2',
#                       'c@wf13',
#                       'c@wf28',
#                       'c@wf29',
#                       'association@j00021',
#                       'foreigners@full_fc_em_jbs',
#                       'c@wf35',
#                       'c@wf8',
#                       'foreigners@fc_empmidchinese_jbs',
#                       'c@wf31',
#                       'indexjob@ij013',
#                       'indexjob@ij003',
#                       'c@wf1'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 8,
#                                                  'speaking': 8,
#                                                  'reading': 8,
#                                                  'writing': 8}}],
#            'acceptRole': [],
#            'employeeCount': 4500,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 0.43282175,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/0000/97176270000/logo.jpg?v=20260319154716',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786101280,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260730',
#            'applyCnt': 19,
#            'coIndustry': 1001001006,
#            'coIndustryDesc': '其它軟體及網路相關業',
#            'custName': '悟空科技股份有限公司',
#            'custNo': '80682392000',
#            'description': '-具Python使用經驗\n'
#                           '-具PyTorch 使用經驗\n'
#                           '-具Git 與 CI/CD 流程（GitLab CI、GitHub Actions）使用經驗\n'
#                           '-具獨立研究開源程式碼相關經驗\n'
#                           '-具Linux環境、Docker、Anaconda、GCP等相關',
#            'descSnippet': '-具[[[Python]]]使用經驗\n'
#                           '-具PyTorch 使用經驗\n'
#                           '-具Git 與 CI/CD 流程（GitLab CI、GitHub Actions）使用經驗\n'
#                           '-具獨立研究開源程式碼相關經驗\n'
#                           '-具Linux環境、Docker、Anaconda、GCP等相關',
#            'mrtDist': 0.4,
#            'jobAddress': '建國北路一段90號5樓之3(丙園金融大樓）',
#            'jobAddrNo': 6001001003,
#            'jobAddrNoDesc': '台北市中山區',
#            'jobName': 'AI工程師Python',
#            'jobNameSnippet': 'AI工程師[[[Python]]]',
#            'jobNo': '14882908',
#            'jobRo': 1,
#            'jobType': 0,
#            'lat': 25.0500012,
#            'lon': 121.5362706,
#            'link': {'job': 'https://www.104.com.tw/job/8uzq4',
#                     'cust': 'https://www.104.com.tw/company/112c7o3k',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8uzq4?channel=104rpt'},
#            'major': [],
#            'mrt': '99001003016',
#            'mrtDesc': '捷運松江南京站',
#            'optionEdu': [4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            'salaryHigh': 9999999,
#            'salaryLow': 45000,
#            'tags': {'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf18': {'desc': '', 'param': 'wf18'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'landmark': {'desc': '距捷運松江南京站約400公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '平日9:00-17:00',
#            'hrBehaviorPR': 0.9591303478386455,
#            'jobCat': [2007001020, 2007001012, 2007001022],
#            'labels': ['association@j00021',
#                       'c@wf7',
#                       'c@wf10',
#                       'indexjob@ij017',
#                       'c@wf18',
#                       'c@wf1',
#                       'indexjob@ij039',
#                       'association@j00020'],
#            'languageRequirements': [],
#            'acceptRole': [],
#            'employeeCount': 10,
#            'pcSkills': [{'code': '12001002016', 'description': 'Github'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001003086', 'description': 'PyTorch'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001001007', 'description': 'Linux'}],
#            'pddScore': 0.412249,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/2000/80682392000/logo.png?v=20250416150709',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786166829,
#                                  'lastCustReplyTimestamp': 1786081809,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260721',
#            'applyCnt': 3,
#            'coIndustry': 1001001002,
#            'coIndustryDesc': '電腦軟體服務業',
#            'custName': 'Linker Vision Co., Ltd._鑫蘊林科股份有限公司',
#            'custNo': '130000000184064',
#            'description': ' systems\n'
#                           '▸ Proficient in Python and experienced with Python '
#                           'web frameworks (we use Django and FastAPI)\n'
#                           '▸ Experience designing',
#            'descSnippet': ' systems\n'
#                           '▸ Proficient in [[[Python]]] and experienced with '
#                           '[[[Python]]] web frameworks (we use Django and '
#                           'FastAPI)\n'
#                           '▸ Experience designing',
#            'mrtDist': 0,
#            'jobAddress': '',
#            'jobAddrNo': 6001001005,
#            'jobAddrNoDesc': '台北市大安區',
#            'jobName': '[台北/高雄] 資深後端工程師 Senior Backend Engineer (Python/Django)',
#            'jobNameSnippet': '[台北/高雄] 資深後端工程師 Senior Backend Engineer '
#                              '([[[Python]]]/Django)',
#            'jobNo': '12642985',
#            'jobRo': 1,
#            'jobType': 2,
#            'lat': 25.0249441,
#            'lon': 121.5433783,
#            'link': {'job': 'https://www.104.com.tw/job/7ize1',
#                     'cust': 'https://www.104.com.tw/company/1a2x6blxc0',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/7ize1?channel=104rpt'},
#            'major': ['資訊工程相關'],
#            'mrt': '',
#            'mrtDesc': '',
#            'optionEdu': [4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 10,
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf29': {'desc': '', 'param': 'wf29'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf26': {'desc': '', 'param': 'wf26'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.704673769344428,
#            'jobCat': [2007001004],
#            'labels': ['c@2026career',
#                       'c@wf29',
#                       'association@j00025',
#                       'c@graduates_welcome',
#                       'c@wf9',
#                       'c@wf26',
#                       'foreigners@full_fc_em_jbs',
#                       'association@j00021',
#                       'association@j00002_002',
#                       'indexjob@ij017',
#                       'association@j00024'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 8,
#                                                  'speaking': 8,
#                                                  'reading': 8,
#                                                  'writing': 8}}],
#            'acceptRole': [2],
#            'employeeCount': 70,
#            'pcSkills': [{'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001002018', 'description': 'Git'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001004039', 'description': 'PostgreSQL'},
#                         {'code': '12001005023', 'description': 'AWS'},
#                         {'code': '12001006017', 'description': 'JavaScript'},
#                         {'code': '12001006043', 'description': 'Django'}],
#            'pddScore': 0.38160083,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/4064/130000000184064/logo.png?v=20260106223007',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1785995113,
#                                  'lastCustReplyTimestamp': 1785293036,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260807',
#            'applyCnt': 6,
#            'coIndustry': 1002007001,
#            'coIndustryDesc': '化學原料製造業',
#            'custName': '長春石油化學股份有限公司',
#            'custNo': '11384806000',
#            'description': '1. 負責財務部門推動作業自動化、數位改善、流程優化等財務會計相關專業\n'
#                           '2. 財會數據追蹤、管理、分析\n'
#                           '3. 具備基礎程式設計能力Python或自動化腳本撰寫能力\n'
#                           '4. 具備 RPA 工具（如 UiPath）基礎能力或有學習意願\n'
#                           '5. 瞭解財務報',
#            'descSnippet': '1. 負責財務部門推動作業自動化、數位改善、流程優化等財務會計相關專業\n'
#                           '2. 財會數據追蹤、管理、分析\n'
#                           '3. 具備基礎程式設計能力[[[Python]]]或自動化腳本撰寫能力\n'
#                           '4. 具備 RPA 工具（如 UiPath）基礎能力或有學習意願\n'
#                           '5. 瞭解財務報',
#            'mrtDist': 0.17,
#            'jobAddress': '松江路301號7樓(104)',
#            'jobAddrNo': 6001001003,
#            'jobAddrNoDesc': '台北市中山區',
#            'jobName': '【台北公司】RPA財會專案管理師(歡迎具財會、資訊背景)',
#            'jobNameSnippet': '【台北公司】RPA財會專案管理師(歡迎具財會、資訊背景)',
#            'jobNo': '15247857',
#            'jobRo': 1,
#            'jobType': 2,
#            'lat': 25.0611843,
#            'lon': 121.5334008,
#            'link': {'job': 'https://www.104.com.tw/job/92tbl',
#                     'cust': 'https://www.104.com.tw/company/58a7wj4',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/92tbl?channel=104rpt'},
#            'major': ['會計學相關', '資訊管理相關', '企業管理相關'],
#            'mrt': '99001004009',
#            'mrtDesc': '捷運行天宮站',
#            'optionEdu': [4, 5],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 50,
#            'salaryHigh': 9999999,
#            'salaryLow': 55000,
#            'tags': {'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf35': {'desc': '', 'param': 'wf35'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf16': {'desc': '', 'param': 'wf16'},
#                     'landmark': {'desc': '距捷運行天宮站約170公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '08:30~17:30',
#            'hrBehaviorPR': 0.7682423649917234,
#            'jobCat': [2003001005, 2004003003, 2004003002],
#            'labels': ['c@wf3',
#                       'association@j00002_002',
#                       'foreigners@fc_emp5m_jbs',
#                       'indexjob@ij039',
#                       'c@wf4',
#                       'foreigners@full_fc_em_jbs',
#                       'c@wf2',
#                       'c@wf1',
#                       'indexjob@ij003',
#                       'c@graduates_welcome',
#                       'c@wf7',
#                       'c@wf35',
#                       'association@j00001',
#                       'indexjob@ij020',
#                       'c@wf9',
#                       'foreigners@overseasStudents_tick',
#                       'c@wf10',
#                       'indexjob@ij013',
#                       'indexjob@ij052',
#                       'c@wf16'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 8,
#                                                  'speaking': 8,
#                                                  'reading': 8,
#                                                  'writing': 8}}],
#            'acceptRole': [2, 65536],
#            'employeeCount': 3300,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 0.37774906,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/6000/11384806000/logo.png?v=20260724101700',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786071493,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260501',
#            'applyCnt': 19,
#            'coIndustry': 1001001002,
#            'coIndustryDesc': '電腦軟體服務業',
#            'custName': '凌科資訊有限公司',
#            'custNo': '130000000262338',
#            'description': '【工作內容 Responsibilities】\n'
#                           '\n'
#                           '* 後端系統開發： 使用 Golang 或 Python 設計並維護高可用性、高擴展性的後端服務與 '
#                           'API。\n'
#                           '\n'
#                           '* 獨立模組負責： 能夠獨立負責從需求分析、系統設計到程式實作的完整功能模組開發。',
#            'descSnippet': '【工作內容 Responsibilities】\n'
#                           '\n'
#                           '* 後端系統開發： 使用 Golang 或 [[[Python]]] '
#                           '設計並維護高可用性、高擴展性的後端服務與 API。\n'
#                           '\n'
#                           '* 獨立模組負責： 能夠獨立負責從需求分析、系統設計到程式實作的完整功能模組開發。',
#            'mrtDist': 0,
#            'jobAddress': '',
#            'jobAddrNo': 6001001010,
#            'jobAddrNoDesc': '台北市內湖區',
#            'jobName': 'Software Engineer (Golang/Python)',
#            'jobNameSnippet': 'Software Engineer (Golang/[[[Python]]])',
#            'jobNo': '14950709',
#            'jobRo': 1,
#            'jobType': 0,
#            'lat': 25.0689422,
#            'lon': 121.5909027,
#            'link': {'job': 'https://www.104.com.tw/job/8wg1h',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bnlqa',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8wg1h?channel=104rpt'},
#            'major': ['資訊工程相關', '其他數學及電算機科學相關', '數理統計相關'],
#            'mrt': '',
#            'mrtDesc': '',
#            'optionEdu': [4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 1,
#            's10': 60,
#            'salaryHigh': 1800000,
#            'salaryLow': 800000,
#            'tags': {'remote': {'desc': '遠端工作'},
#                     'wf8': {'desc': '', 'param': 'wf8'},
#                     'wf12': {'desc': '', 'param': 'wf12'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.6321442458311577,
#            'jobCat': [2007001016, 2007001004, 2007001012],
#            'labels': ['deboost@kwdeboost_link_1',
#                       'indexjob@ij005',
#                       'association@j00021',
#                       'c@graduates_welcome',
#                       'c@wf8',
#                       'indexjob@ij010',
#                       'senior@senior_job_H',
#                       'indexjob@ij022',
#                       'indexjob@ij039',
#                       'c@wf12'],
#            'languageRequirements': [],
#            'acceptRole': [2, 32768],
#            'employeeCount': 0,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001002018', 'description': 'Git'}],
#            'pddScore': 0.37521574,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/2338/130000000262338/logo.png?v=20260430224852',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': None,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260802',
#            'applyCnt': 12,
#            'coIndustry': 1001001001,
#            'coIndustryDesc': '電腦系統整合服務業',
#            'custName': '凱衛資訊股份有限公司',
#            'custNo': '21261212000',
#            'description': '合最佳化、風險分析及金融演算法等領域。 \n'
#                           '• 開發量子演算法、最佳化模型及應用程式，將研究成果落實於實際金融場景。 \n'
#                           '• 使用 Python 開發量子應用、自動化工具及相關技術平台。 \n'
#                           '• 建置與優化 Linux、GPU、Docker 等高效能運算',
#            'descSnippet': '合最佳化、風險分析及金融演算法等領域。 \n'
#                           '• 開發量子演算法、最佳化模型及應用程式，將研究成果落實於實際金融場景。 \n'
#                           '• 使用 [[[Python]]] 開發量子應用、自動化工具及相關技術平台。 \n'
#                           '• 建置與優化 Linux、GPU、Docker 等高效能運算',
#            'mrtDist': 0,
#            'jobAddress': '光復北路11巷29號2樓',
#            'jobAddrNo': 6001001004,
#            'jobAddrNoDesc': '台北市松山區',
#            'jobName': '金融科技前瞻研發｜量子運算研究工程師（Python）',
#            'jobNameSnippet': '金融科技前瞻研發｜量子運算研究工程師（[[[Python]]]）',
#            'jobNo': '15308894',
#            'jobRo': 1,
#            'jobType': 0,
#            'lat': 25.0496106,
#            'lon': 121.5585985,
#            'link': {'job': 'https://www.104.com.tw/job/944f2',
#                     'cust': 'https://www.104.com.tw/company/9rmdk68',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/944f2?channel=104rpt'},
#            'major': ['資訊工程相關', '電機電子工程相關', '應用數學相關'],
#            'mrt': '',
#            'mrtDesc': '',
#            'optionEdu': [4, 5, 6],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 10,
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'zone': {'desc': '上市上櫃', 'param': 16},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf12': {'desc': '', 'param': 'wf12'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf31': {'desc': '', 'param': 'wf31'},
#                     'wf4': {'desc': '', 'param': 'wf4'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf32': {'desc': '', 'param': 'wf32'}},
#            's9': [1],
#            's5': 0,
#            'd3': '彈性上下班，上班時間8:00~9:30，下班時間17:00~18:30',
#            'hrBehaviorPR': 0.8646839900903203,
#            'jobCat': [2007001012, 2007001004],
#            'labels': ['indexjob@ij026',
#                       'indexjob@ij010',
#                       'c@wf9',
#                       'c@wf3',
#                       'c@graduates_welcome',
#                       'indexjob@ij003',
#                       'c@wf10',
#                       'c@wf12',
#                       'c@wf26',
#                       'c@wf31',
#                       'c@wf4',
#                       'c@wf2',
#                       'indexjob@ij017',
#                       'c@wf7',
#                       'indexjob@ij025',
#                       'c@wf1',
#                       'c@wf32'],
#            'languageRequirements': [],
#            'acceptRole': [2],
#            'employeeCount': 140,
#            'pcSkills': [{'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001002018', 'description': 'Git'}],
#            'pddScore': 0.32827795,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/2000/21261212000/logo.jpg?v=20260713180308',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786080454,
#                                  'lastCustReplyTimestamp': 1786080756,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260721',
#            'applyCnt': 13,
#            'coIndustry': 1001001002,
#            'coIndustryDesc': '電腦軟體服務業',
#            'custName': 'Linker Vision Co., Ltd._鑫蘊林科股份有限公司',
#            'custNo': '130000000184064',
#            'description': ' for future use\n'
#                           '\n'
#                           'What Skill/Experience You Must Have:\n'
#                           '▸ Proficient in Python and Experience Python web '
#                           'frameworks (We use',
#            'descSnippet': ' for future use\n'
#                           '\n'
#                           'What Skill/Experience You Must Have:\n'
#                           '▸ Proficient in [[[Python]]] and Experience '
#                           '[[[Python]]] web frameworks (We use',
#            'mrtDist': 0.49,
#            'jobAddress': '忠孝東路三段136號9樓之5',
#            'jobAddrNo': 6001001005,
#            'jobAddrNoDesc': '台北市大安區',
#            'jobName': '[台北/高雄] 後端工程師 Backend Engineer (Python/Django)',
#            'jobNameSnippet': '[台北/高雄] 後端工程師 Backend Engineer '
#                              '([[[Python]]]/Django)',
# ...
#            'descSnippet': ' Monitoring and alerting \n'
#                           '10.AI workflow design & MCP \n'
#                           '11.AI server management \n'
#                           '\n'
#                           'Programming Language: Java, C#, [[[Python]]], Go,',
#            'mrtDist': 0,
#            'jobAddress': '',
#            'jobAddrNo': 6001001011,
#            'jobAddrNoDesc': '台北市南港區',
#            'jobName': 'Platform Engineer_RSBU SWRD',
#            'jobNameSnippet': 'Platform Engineer_RSBU SWRD',
#            'jobNo': '14558001',
#            'jobRo': 1,
#            'jobType': 2,
#            'lat': 25.0312347,
#            'lon': 121.6111949,
#            'link': {'job': 'https://www.104.com.tw/job/8o10x',
#                     'cust': 'https://www.104.com.tw/company/1a2x6blrbc',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8o10x?channel=104rpt'},
#            'major': ['資訊工程相關', '資訊管理相關'],
#            'mrt': '',
#            'mrtDesc': '',
#            'optionEdu': [4, 5],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 10,
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf30': {'desc': '', 'param': 'wf30'},
#                     'wf25': {'desc': '', 'param': 'wf25'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf1': {'desc': '', 'param': 'wf1'}},
#            's9': [1],
#            's5': 0,
#            'd3': '09:00~18:00',
#            'hrBehaviorPR': 0.5869818803950541,
#            'jobCat': [2007001004, 2007002006, 2007002010],
#            'labels': ['c@wf9',
#                       'c@wf3',
#                       'c@wf30',
#                       'indexjob@ij017',
#                       'c@wf25',
#                       'c@wf2',
#                       'c@wf7',
#                       'c@wf1',
#                       'c@graduates_welcome'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 8,
#                                                  'speaking': 8,
#                                                  'reading': 2,
#                                                  'writing': 2}}],
#            'acceptRole': [2],
#            'employeeCount': 750,
#            'pcSkills': [{'code': '12001003009', 'description': 'C#'},
#                         {'code': '12001003025', 'description': 'Java'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001003080', 'description': 'Go'}],
#            'pddScore': 0.14553519,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/6264/130000000176264/logo.png?v=20241219131131',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786159521,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260729',
#            'applyCnt': 5,
#            'coIndustry': 1004002002,
#            'coIndustryDesc': '證券及期貨業',
#            'custName': '中國信託綜合證券股份有限公司',
#            'custNo': '130000000111548',
#            'description': '1. 交易系統功能開發\n2. 交易系統作業維運',
#            'descSnippet': '1. 交易系統功能開發\n2. 交易系統作業維運',
#            'mrtDist': 0.12,
#            'jobAddress': '經貿二路188號14樓',
#            'jobAddrNo': 6001001011,
#            'jobAddrNoDesc': '台北市南港區',
#            'jobName': '衍商_交易系統開發工程師',
#            'jobNameSnippet': '衍商_交易系統開發工程師',
#            'jobNo': '14542086',
#            'jobRo': 1,
#            'jobType': 2,
#            'lat': 25.0592406,
#            'lon': 121.6151628,
#            'link': {'job': 'https://www.104.com.tw/job/8noqu',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bkddo',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8noqu?channel=104rpt'},
#            'major': ['數理統計相關', '資訊工程相關'],
#            'mrt': '99001001023',
#            'mrtDesc': '捷運南港軟體園區站',
#            'optionEdu': [4, 5],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 10,
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf34': {'desc': '', 'param': 'wf34'},
#                     'wf27': {'desc': '', 'param': 'wf27'},
#                     'wf18': {'desc': '', 'param': 'wf18'},
#                     'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf23': {'desc': '', 'param': 'wf23'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf28': {'desc': '', 'param': 'wf28'},
#                     'wf3': {'desc': '', 'param': 'wf3'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'landmark': {'desc': '距捷運南港軟體園區站約120公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.34973392732160913,
#            'jobCat': [2007001009, 2007001004],
#            'labels': ['c@wf34',
#                       'association@j00021',
#                       'c@wf27',
#                       'c@wf18',
#                       'c@wf2',
#                       'c@wf9',
#                       'c@wf7',
#                       'c@wf23',
#                       'c@wf26',
#                       'c@wf10',
#                       'c@wf28',
#                       'c@wf3',
#                       'c@wf1'],
#            'languageRequirements': [],
#            'acceptRole': [],
#            'employeeCount': 700,
#            'pcSkills': [{'code': '12001003009', 'description': 'C#'},
#                         {'code': '12001003045', 'description': 'Python'}],
#            'pddScore': 0.1450623,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/1548/130000000111548/logo.png?v=20260512161001',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786061173,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260807',
#            'applyCnt': 3,
#            'coIndustry': 1009001002,
#            'coIndustryDesc': '人力派遣服務',
#            'custName': '智誠科技服務股份有限公司',
#            'custNo': '130000000051729',
#            'description': '1.獨立設計開發自動化測試工具(Powershell/Python)、執行程式驗證測試。\n'
#                           '2.協助分析釐清測試問題並視需求修改程式。\n'
#                           '3.開發與建置自動化測試環境架構，Server更新維護與錯誤排除。',
#            'descSnippet': '1.獨立設計開發自動化測試工具(Powershell/[[[Python]]])、執行程式驗證測試。\n'
#                           '2.協助分析釐清測試問題並視需求修改程式。\n'
#                           '3.開發與建置自動化測試環境架構，Server更新維護與錯誤排除。',
#            'mrtDist': 0,
#            'jobAddress': '',
#            'jobAddrNo': 6001001011,
#            'jobAddrNoDesc': '台北市南港區',
#            'jobName': 'Automation Development Engineer',
#            'jobNameSnippet': 'Automation Development Engineer',
#            'jobNo': '14986726',
#            'jobRo': 1,
#            'jobType': 0,
#            'lat': 25.0312347,
#            'lon': 121.6111949,
#            'link': {'job': 'https://www.104.com.tw/job/8x7ty',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bj381',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/8x7ty?channel=104rpt'},
#            'major': ['資訊工程相關', '電機電子工程相關', '資訊管理相關'],
#            'mrt': '',
#            'mrtDesc': '',
#            'optionEdu': [3, 4, 5],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 10,
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf2': {'desc': '', 'param': 'wf2'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'wf9': {'desc': '', 'param': 'wf9'},
#                     'wf1': {'desc': '', 'param': 'wf1'}},
#            's9': [1],
#            's5': 0,
#            'd3': '9:00-18:00',
#            'hrBehaviorPR': 0.6290824658660416,
#            'jobCat': [2009003007, 2007001004],
#            'labels': ['association@j00018',
#                       'c@graduates_welcome',
#                       'c@wf2',
#                       'c@wf10',
#                       'association@j00021',
#                       'c@wf7',
#                       'c@wf26',
#                       'association@j00014',
#                       'c@wf9',
#                       'c@wf1'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 8,
#                                                  'speaking': 8,
#                                                  'reading': 8,
#                                                  'writing': 8}}],
#            'acceptRole': [2, 64, 2048],
#            'employeeCount': 0,
#            'pcSkills': [{'code': '12001001007', 'description': 'Linux'},
#                         {'code': '12001001045',
#                          'description': 'Windows Server 2012'},
#                         {'code': '12001001041',
#                          'description': 'Windows Server 2008'},
#                         {'code': '12001001047',
#                          'description': 'Windows Server 2019'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001001020', 'description': 'Shell'}],
#            'pddScore': 0.14419001,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/1729/130000000051729/logo.gif?v=20250829105037',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1785837870,
#                                  'lastCustReplyTimestamp': None,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None},
#           {'appearDate': '20260804',
#            'applyCnt': 4,
#            'coIndustry': 1001001006,
#            'coIndustryDesc': '其它軟體及網路相關業',
#            'custName': 'inline_樂排股份有限公司',
#            'custNo': '130000000108019',
#            'description': ' training\n'
#                           '\n'
#                           '\n'
#                           'Operations & System Optimization\n'
#                           '\n'
#                           'Utilize Python, Excel (advanced functions & pivot '
#                           'tables), and Google Apps Script (',
#            'descSnippet': ' training\n'
#                           '\n'
#                           '\n'
#                           'Operations & System Optimization\n'
#                           '\n'
#                           'Utilize [[[Python]]], Excel (advanced functions & '
#                           'pivot tables), and Google Apps Script (',
#            'mrtDist': 0.32,
#            'jobAddress': '北平東路30-1號5樓（匯泰大樓）',
#            'jobAddrNo': 6001001001,
#            'jobAddrNoDesc': '台北市中正區',
#            'jobName': 'Revenue Operations – Senior Collection & Compliance '
#                       'Specialist',
#            'jobNameSnippet': 'Revenue Operations – Senior Collection & '
#                              'Compliance Specialist',
#            'jobNo': '15314645',
#            'jobRo': 1,
#            'jobType': 2,
#            'lat': 25.0455757,
#            'lon': 121.5264634,
#            'link': {'job': 'https://www.104.com.tw/job/948ut',
#                     'cust': 'https://www.104.com.tw/company/1a2x6bkann',
#                     'applyAnalyze': 'https://www.104.com.tw/jobs/apply/analysis/948ut?channel=104rpt'},
#            'major': [],
#            'mrt': '99001005013',
#            'mrtDesc': '捷運善導寺站',
#            'optionEdu': [4, 5],
#            'period': 0,
#            'remoteWorkType': 0,
#            's10': 10,
#            'salaryHigh': 0,
#            'salaryLow': 0,
#            'tags': {'wf12': {'desc': '', 'param': 'wf12'},
#                     'wf8': {'desc': '', 'param': 'wf8'},
#                     'wf10': {'desc': '', 'param': 'wf10'},
#                     'wf7': {'desc': '', 'param': 'wf7'},
#                     'wf13': {'desc': '', 'param': 'wf13'},
#                     'wf1': {'desc': '', 'param': 'wf1'},
#                     'wf26': {'desc': '', 'param': 'wf26'},
#                     'landmark': {'desc': '距捷運善導寺站約320公尺'}},
#            's9': [1],
#            's5': 0,
#            'd3': '',
#            'hrBehaviorPR': 0.9368580093986424,
#            'jobCat': [2001001002, 2003001008, 2003001007],
#            'labels': ['c@wf12',
#                       'association@j00002_001',
#                       'association@j00021',
#                       'c@wf8',
#                       'indexjob@ij010',
#                       'indexjob@ij001',
#                       'c@wf10',
#                       'c@wf7',
#                       'c@wf13',
#                       'c@new_company_job',
#                       'foreigners@foreigners',
#                       'indexjob@ij005',
#                       'indexjob@ij009',
#                       'c@wf1',
#                       'c@wf26',
#                       'indexjob@ij070',
#                       'association@j00025'],
#            'languageRequirements': [{'language': 1,
#                                      'ability': {'listening': 2,
#                                                  'speaking': 2,
#                                                  'reading': 2,
#                                                  'writing': 2}}],
#            'acceptRole': [],
#            'employeeCount': 150,
#            'pcSkills': [{'code': '12001008003', 'description': 'Excel'},
#                         {'code': '12001003045', 'description': 'Python'},
#                         {'code': '12001008012', 'description': 'PowerPoint'}],
#            'pddScore': 0.13945228,
#            'custLogo': 'https://static.104.com.tw/b_profile/cust_picture/8019/130000000108019/logo.png?v=20260727181425',
#            'jobSwitch': 'on',
#            'isSave': None,
#            'interactionRecord': {'lastProcessedResumeAtTime': 1786114265,
#                                  'lastCustReplyTimestamp': 1786199305,
#                                  'nowTimestamp': 1786258707},
#            'isApplied': None,
#            'applyDate': None,
#            'userApplyCount': None}],
#  'metadata': {'pagination': {'count': 31,
#                              'currentPage': 1,
#                              'lastPage': 39,
#                              'total': 1156},
#               'isPreciseHotJob': False,
#               'filterQuery': {'order': 15,
#                               'asc': 0,
#                               'keyword': 'python',
#                               'fz': 8,
#                               'kwop': 7,
#                               'excludeKwFz': 4,
#                               'excludeKwKwop': 8,
#                               'enableJobNoTopOrder': 1,
#                               'area': ['6001001000'],
#                               'jobexp': ['1'],
#                               'ro': ['1'],
#                               'scstrict': 0,
#                               'scneg': 0,
#                               'page': 1,
#                               'pagesize': 30},
#               'offJobs': [],
#               'personalBoost': 0}}
# ['9316i', '72zcd', '8zy25', '7csnw', '8osoz', '8i0ux', '8uzq4', '7ize1', '92tbl', '8wg1h', '944f2', '7izdv', '5u8ui', '6yjxf', '92jml', '8n883', '8p6em', '8zflw', '8tfqn', '8rbbl', '93vxg', '8tn3e', '8wiak', '8zq1f', '8tfmd', '8bxxi', '86auy', '8o10x', '8noqu', '8x7ty', '948ut']

# %%
#print(data['data'][0]['link']['job'][-5:])
# Out:
# 9316i

# %%
# job_id_list = []

# for item in data['data']:
#     job_id_list.append(item['link']['job'][-5:])

# print(job_id_list)
# Out:
# ['9316i', '72zcd', '8zy25', '7csnw', '8osoz', '8i0ux', '8uzq4', '7ize1', '92tbl', '8wg1h', '944f2', '7izdv', '5u8ui', '6yjxf', '92jml', '8n883', '8p6em', '8zflw', '8tfqn', '8rbbl', '93vxg', '8tn3e', '8wiak', '8zq1f', '8tfmd', '8bxxi', '86auy', '8o10x', '8noqu', '8x7ty', '948ut']

# %%
import requests
def get_job_deails(job_id):
    url = f'https://www.104.com.tw/api/jobs/{job_id}'
    c_headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/150.0.0.0 Safari/537.36",
    "Referer" : "https://www.104.com.tw/"
}
    r = requests.get(url,headers=c_headers)
    datatest = r.json()
    job_details_keepkeys = [
        'jobDescription','salary','addressRegion','addressDetail' #jobDescription在jobDetail裡面 salary也在jobDetail裡面
    ]
    job_details_list = {
        key: (datatest['data']['jobDetail'][key]).replace("\n","").replace("\r","")
        for key in job_details_keepkeys
    }

    #pprint(datatest['data']['jobDetail']['jobDescription'])
    pprint(job_details_list)
    #print("="*20)
    #print(datatest)
get_job_deails('8osoz')
# Out:
# {'addressDetail': '杭州北路26號12樓 (新光華山金融中心)',
#  'addressRegion': '台北市中正區',
#  'jobDescription': '我們是國內領先的雲端智能數據分析公司，專注於AI 及數據應用技術，誠摯邀請對智能數據 (Data '
#                    'Intelligence) 充滿熱情的你，一同開拓未來！我們正在尋找具備實務經驗與獨立問題解決能力的 Python '
#                    '工程師加入團隊。我們理解並接受團隊成員善用各種AI技術工具提升開發效率，但更重視你是否具備以下能力：1、能主動透過閱讀技術文件或原始碼理解技術細節並且實作。2、能清楚解釋自己的開發思路與實務解決方案，而非單純依賴 '
#                    'AI 工具的建議。3、使用工具同時，保持主動思考與獨立判斷能力，能辨別解決方案的合理性與潛在問題。 如果你擅長將 '
#                    'AI 工具視為輔助，但仍能自主學習、思考與問題解決，我們誠摯歡迎你加入團隊。工作內容：系統與 API 開發：- '
#                    '設計、開發與維護 RESTful API 與後端服務- '
#                    '撰寫模組化且可維護的程式碼，確保系統穩定運作資料處理與流程整合：- 處理與儲存各類結構化、非結構化資料- '
#                    '開發有效率的資料存取與檢索流程，滿足前端及第三方系統的整合需求。技術研究與嘗試- '
#                    '與AI團隊合作，開發整合生成式AI模型（如向量資料庫、LLM 等）的實務應用。必備技能1、熟練 '
#                    'Python，具備紮實的程式架構設計與實務開發經驗。2、熟悉至少一種 Python '
#                    '後端框架（FastAPI、Flask、Django），能獨立設計並實作 RESTful '
#                    'API。3、具備實際處理資料與設計資料庫 schema 的經驗，能清楚描述你的解決方案。4、熟悉 Git '
#                    '版本控制，有良好的團隊協作與溝通能力。加分條件1、對生成式 AI、LLM、LangChain '
#                    '等技術有基礎認識，能具體說明曾參與的專案或應用場景。2、具備向量資料庫（如 '
#                    'FAISS、Milvus、Pinecone）的應用實務經驗。3、有 Docker '
#                    '開發與部署經驗，熟悉容器化環境部署。同時，我們將提供：★完善的專業技術資源與發展支援★定期技術分享與跨部門協作機會★透明的職涯發展與晉升管道準備好迎接 '
#                    'AI 時代的挑戰了嗎？歡迎投遞履歷，與我們一起成長！',
#  'salary': '月薪40,000~55,000元'}

# %%
keep_keys = ['appearDate', 'applyCnt', 'custName', 'jobName', 'jobAddrNoDesc','jobAddress', 'link']

filtered_list = []

target_list = data['data']

# filtered_list = [
#     {
#         k: (
#         (item[k].replace('\n', '').replace('\r','') if k == 'description' else item[k]))
#         for k in keep_keys if k in item
#     }
#     for item in target_list
# ] #清洗資料 只保留keep_keys要求的鍵值，再加上三元運算，如果key=description則觸發replace"\n" "\r" 剩下的則原封不動放入filtered_list



for data_list in target_list:
    new_data = {
        key: data_list[key]
        for key in keep_keys
        if key in data_list
    }
    if 'link' in data_list and 'job' in data_list['link']:
        new_data['link'] = item['link']['job']

    filtered_list.append(new_data)

pprint(filtered_list,sort_dicts=False)
    
#pprint(target_list,sort_dicts=False)





#pprint(filtered_list, sort_dicts=False)
# Out:
# [{'appearDate': '20260721',
#   'applyCnt': 2,
#   'custName': '台灣壽司郎股份有限公司',
#   'jobName': '資訊部助理/專員/組長',
#   'jobAddrNoDesc': '台北市中山區',
#   'jobAddress': '松江路61-1號3樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260519',
#   'applyCnt': 6,
#   'custName': '學力創意科技股份有限公司',
#   'jobName': 'Python工程師((Web/APP/IoT開發))',
#   'jobAddrNoDesc': '台北市大安區',
#   'jobAddress': '信義路四段55號2樓之1',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260803',
#   'applyCnt': 5,
#   'custName': '艾帝浦杰股份有限公司',
#   'jobName': 'Python程式設計師(PG)(臺北市南港區)',
#   'jobAddrNoDesc': '台北市南港區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260803',
#   'applyCnt': 7,
#   'custName': '意藍資訊股份有限公司',
#   'jobName': 'P7-Python資料工程師',
#   'jobAddrNoDesc': '台北市中正區',
#   'jobAddress': '杭州北路26號12樓 (新光華山金融中心)',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260803',
#   'applyCnt': 9,
#   'custName': '意藍資訊股份有限公司',
#   'jobName': 'P10-Python應用工程師',
#   'jobAddrNoDesc': '台北市中正區',
#   'jobAddress': '杭州北路26號12樓 (新光華山金融中心)',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260804',
#   'applyCnt': 13,
#   'custName': '台灣大哥大股份有限公司',
#   'jobName': 'I105 Python Web工程師(可遠端工作)',
#   'jobAddrNoDesc': '台北市大安區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260730',
#   'applyCnt': 19,
#   'custName': '悟空科技股份有限公司',
#   'jobName': 'AI工程師Python',
#   'jobAddrNoDesc': '台北市中山區',
#   'jobAddress': '建國北路一段90號5樓之3(丙園金融大樓）',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260721',
#   'applyCnt': 3,
#   'custName': 'Linker Vision Co., Ltd._鑫蘊林科股份有限公司',
#   'jobName': '[台北/高雄] 資深後端工程師 Senior Backend Engineer (Python/Django)',
#   'jobAddrNoDesc': '台北市大安區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260807',
#   'applyCnt': 6,
#   'custName': '長春石油化學股份有限公司',
#   'jobName': '【台北公司】RPA財會專案管理師(歡迎具財會、資訊背景)',
#   'jobAddrNoDesc': '台北市中山區',
#   'jobAddress': '松江路301號7樓(104)',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260501',
#   'applyCnt': 19,
#   'custName': '凌科資訊有限公司',
#   'jobName': 'Software Engineer (Golang/Python)',
#   'jobAddrNoDesc': '台北市內湖區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260802',
#   'applyCnt': 12,
#   'custName': '凱衛資訊股份有限公司',
#   'jobName': '金融科技前瞻研發｜量子運算研究工程師（Python）',
#   'jobAddrNoDesc': '台北市松山區',
#   'jobAddress': '光復北路11巷29號2樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260721',
#   'applyCnt': 13,
#   'custName': 'Linker Vision Co., Ltd._鑫蘊林科股份有限公司',
#   'jobName': '[台北/高雄] 後端工程師 Backend Engineer (Python/Django)',
#   'jobAddrNoDesc': '台北市大安區',
#   'jobAddress': '忠孝東路三段136號9樓之5',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260804',
#   'applyCnt': 10,
#   'custName': '頤合資訊股份有限公司',
#   'jobName': '資安SIEM工程師｜XSIAM新戰線．Python自動化．保證13個月',
#   'jobAddrNoDesc': '台北市松山區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260805',
#   'applyCnt': 11,
#   'custName': 'MyGo商學苑_平安房屋仲介股份有限公司',
#   'jobName': '【MyGo AI大數據】Proptech/Fintech-Python後端工程師/資料科學家/數據分析師/資料工程師',
#   'jobAddrNoDesc': '台北市中山區',
#   'jobAddress': '長春路176號4樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260803',
#   'applyCnt': 2,
#   'custName': '艾帝浦杰股份有限公司',
#   'jobName': 'Python程式設計師(PG)(台北市內湖區)',
#   'jobAddrNoDesc': '台北市內湖區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260806',
#   'applyCnt': 15,
#   'custName': '安碁資訊股份有限公司',
#   'jobName': 'Python 後端開發工程師',
#   'jobAddrNoDesc': '台北市南港區',
#   'jobAddress': '南港路三段 9 號 13 樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260716',
#   'applyCnt': 7,
#   'custName': '智群智慧股份有限公司',
#   'jobName': 'AI Engineer-Taipei-SGSC-11473',
#   'jobAddrNoDesc': '台北市南港區',
#   'jobAddress': '園區街3-2號6樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260807',
#   'applyCnt': 6,
#   'custName': '一騰資訊服務股份有限公司',
#   'jobName': '【H001】Python 後端開發工程師（AI）',
#   'jobAddrNoDesc': '台北市南港區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260805',
#   'applyCnt': 4,
#   'custName': '九天資產管理股份有限公司',
#   'jobName': 'Proptech/Fintech Python後端工程師/資料科學家',
#   'jobAddrNoDesc': '台北市中山區',
#   'jobAddress': '長春路176號4樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260804',
#   'applyCnt': 4,
#   'custName': '艾盾資科股份有限公司',
#   'jobName': '資安分析師（Security Analyst）',
#   'jobAddrNoDesc': '台北市中正區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260717',
#   'applyCnt': 5,
#   'custName': '合作金庫人壽保險股份有限公司(總公司)',
#   'jobName': '數位數據分析師',
#   'jobAddrNoDesc': '台北市中山區',
#   'jobAddress': '南京東路二段85號5樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260506',
#   'applyCnt': 6,
#   'custName': '台普威能源股份有限公司',
#   'jobName': '軟體工程師',
#   'jobAddrNoDesc': '台北市內湖區',
#   'jobAddress': '基湖路1號6樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260805',
#   'applyCnt': 5,
#   'custName': '華碩電腦股份有限公司',
#   'jobName': 'RD21994 雲端工程師(顯示器)',
#   'jobAddrNoDesc': '台北市北投區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260807',
#   'applyCnt': 2,
#   'custName': '星眾科技股份有限公司',
#   'jobName': '軟韌體(助理)工程師',
#   'jobAddrNoDesc': '台北市內湖區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260805',
#   'applyCnt': 5,
#   'custName': '九天資產管理股份有限公司',
#   'jobName': 'Proptech/Fintech資料科學家/AI 機器學習工程師',
#   'jobAddrNoDesc': '台北市中山區',
#   'jobAddress': '長春路176號4樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260803',
#   'applyCnt': 6,
#   'custName': '新光醫院_新光醫療財團法人新光吳火獅紀念醫院',
#   'jobName': '[行政]生成式AI工程師',
#   'jobAddrNoDesc': '台北市士林區',
#   'jobAddress': '文昌路95號',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260727',
#   'applyCnt': 12,
#   'custName': '優式機器人股份有限公司',
#   'jobName': '資料科學/深度學習工程師  Data Scientist / Deep Learning Engineer',
#   'jobAddrNoDesc': '台北市內湖區',
#   'jobAddress': '新湖一路151號5樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260804',
#   'applyCnt': 6,
#   'custName': '神基科技股份有限公司',
#   'jobName': 'Platform Engineer_RSBU SWRD',
#   'jobAddrNoDesc': '台北市南港區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260729',
#   'applyCnt': 5,
#   'custName': '中國信託綜合證券股份有限公司',
#   'jobName': '衍商_交易系統開發工程師',
#   'jobAddrNoDesc': '台北市南港區',
#   'jobAddress': '經貿二路188號14樓',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260807',
#   'applyCnt': 3,
#   'custName': '智誠科技服務股份有限公司',
#   'jobName': 'Automation Development Engineer',
#   'jobAddrNoDesc': '台北市南港區',
#   'jobAddress': '',
#   'link': 'https://www.104.com.tw/job/948ut'},
#  {'appearDate': '20260804',
#   'applyCnt': 4,
#   'custName': 'inline_樂排股份有限公司',
#   'jobName': 'Revenue Operations – Senior Collection & Compliance Specialist',
#   'jobAddrNoDesc': '台北市中正區',
#   'jobAddress': '北平東路30-1號5樓（匯泰大樓）',
#   'link': 'https://www.104.com.tw/job/948ut'}]

# %%
print(data['data'][0]['link']['job'])
# Out:
# https://www.104.com.tw/job/9316i

# %%
#area?kw=6001001000 (台北市)
